# %% [markdown]
# #  Import usefull packages

# %%
import spotipy
import pandas as pd
import json
import pprint
import config
from itertools import *
from bs4 import BeautifulSoup as bs
import sys
import random
import requests
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
sp= spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,client_secret=config.client_secret))

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
from sklearn.compose import ColumnTransformer

# %% [markdown]
# # load the big_df
#      songs of the audio features (minimum 500 songs as diverse as possible))
#
# 2- standardise the data using standardscaler (using fit and then transform)
# 3- save the scaler for future use for the new user input song. save it using pickle
# 4- choosing the number of clusters k.
# 5- fitting k means cluster.
# 6- build the elbow graph to find the best k.
# 7- use the model with the best k to assign every observation in your data frame to its cluster number ( adding cluster columns to the pandas data frame) using model.predict
# 8-save the model with the best k as your final model using pickle.
# for the user input tasks and the full scenario:
# 1- get the song name from the user as an input
# 2- play the input song in music embed player.
# 3- get the audio features for that song from spotify API. using sp.audio_features(trackid) . pay attention to keep only the audio features columns.
# 4- load the standardscaler using pickle and use it to scale the new song. (scaler.transform)
# 5- using mode.predict(new scaled audio record for the new song) to predict the cluster (label) for the new song.
# 6- return random song from the same cluster that the new song belongs to from your data frame and suggest it to the user.
# 7- play it using embedded music player.

# %%
first_db= pd.read_csv("6383_rows.csv")

# %%
first_db
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.865   0.665    -6.289       0.0730      0.045300
# 1            0.801   0.910    -6.566       0.2250      0.002390
# 2            0.644   0.846    -5.443       0.2750      0.124000
# 3            0.802   0.787    -6.009       0.2060      0.001270
# 4            0.872   0.723    -5.968       0.2470      0.029300
# ...            ...     ...       ...          ...           ...
# 6378         0.791   0.591    -9.185       0.0478      0.017200
# 6379         0.655   0.794    -5.872       0.2500      0.082000
# 6380         0.757   0.920    -7.697       0.0385      0.000531
# 6381         0.826   0.900    -7.707       0.0697      0.066600
# 6382         0.745   0.853    -8.154       0.0407      0.003340
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.2240    0.331  111.113  1ofhfV90EnYhEr7Un2fWiv
# 1             0.000891    0.0737    0.805   87.277  5g9lS8deSIxItFBmZRC4vN
# 2             0.000000    0.3530    0.503   79.182  1qZqFtSINOOmjYH1UE9805
# 3             0.000181    0.0763    0.806   90.189  7sKt5Y2zJpYw78iAxndB8y
# 4             0.000000    0.3270    0.843   93.279  4VQNCzfZ3MdHEwwErNXpBo
# ...                ...       ...      ...      ...                     ...
# 6378          0.879000    0.1310    0.683  133.974  4LWiFuehm2uY3GK8q8sduT
# 6379          0.079100    0.0457    0.667  187.007  3cCLvbMCHMgX7DLXPr1ALv
# 6380          0.751000    0.0956    0.955  126.001  2MumLWIryjcBG1eRYcRh6I
# 6381          0.275000    0.6790    0.925  120.980  5z0J0ztN5QG0UTRv3wSZQK
# 6382          0.403000    0.1350    0.466  124.011  6k5dL3jGlbliaIQRqkAGcU
#
#       duration_ms
# 0          268827
# 1          278387
# 2          301600
# 3          296907
# 4          307773
# ...           ...
# 6378       428606
# 6379       184939
# 6380       327304
# 6381       306641
# 6382       254091
#
# [6383 rows x 11 columns]

# %% [markdown]
# ## Drop id

# %%
first_db_id=first_db[["id"]]
first_db.drop("id",axis=1, inplace=True)

# %%
first_db
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.865   0.665    -6.289       0.0730      0.045300
# 1            0.801   0.910    -6.566       0.2250      0.002390
# 2            0.644   0.846    -5.443       0.2750      0.124000
# 3            0.802   0.787    -6.009       0.2060      0.001270
# 4            0.872   0.723    -5.968       0.2470      0.029300
# ...            ...     ...       ...          ...           ...
# 6378         0.791   0.591    -9.185       0.0478      0.017200
# 6379         0.655   0.794    -5.872       0.2500      0.082000
# 6380         0.757   0.920    -7.697       0.0385      0.000531
# 6381         0.826   0.900    -7.707       0.0697      0.066600
# 6382         0.745   0.853    -8.154       0.0407      0.003340
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000000    0.2240    0.331  111.113       268827
# 1             0.000891    0.0737    0.805   87.277       278387
# 2             0.000000    0.3530    0.503   79.182       301600
# 3             0.000181    0.0763    0.806   90.189       296907
# 4             0.000000    0.3270    0.843   93.279       307773
# ...                ...       ...      ...      ...          ...
# 6378          0.879000    0.1310    0.683  133.974       428606
# 6379          0.079100    0.0457    0.667  187.007       184939
# 6380          0.751000    0.0956    0.955  126.001       327304
# 6381          0.275000    0.6790    0.925  120.980       306641
# 6382          0.403000    0.1350    0.466  124.011       254091
#
# [6383 rows x 10 columns]

# %%
first_db_id
# Out:
#                           id
# 0     1ofhfV90EnYhEr7Un2fWiv
# 1     5g9lS8deSIxItFBmZRC4vN
# 2     1qZqFtSINOOmjYH1UE9805
# 3     7sKt5Y2zJpYw78iAxndB8y
# 4     4VQNCzfZ3MdHEwwErNXpBo
# ...                      ...
# 6378  4LWiFuehm2uY3GK8q8sduT
# 6379  3cCLvbMCHMgX7DLXPr1ALv
# 6380  2MumLWIryjcBG1eRYcRh6I
# 6381  5z0J0ztN5QG0UTRv3wSZQK
# 6382  6k5dL3jGlbliaIQRqkAGcU
#
# [6383 rows x 1 columns]

# %% [markdown]
# # standardise the data
#     using standardscaler (using fit and then transform)
#
# **for the K-Means is a distance based algorithm:** we need to scale / normalize!:

# %%
first_db.describe()
# Out:
#        danceability       energy     loudness  speechiness  acousticness  \
# count   6383.000000  6383.000000  6383.000000  6383.000000   6383.000000
# mean       0.561902     0.616941    -9.177660     0.091951      0.334626
# std        0.194199     0.262881     5.736263     0.110050      0.349833
# min        0.000000     0.000020   -47.070000     0.000000      0.000001
# 25%        0.433000     0.447000   -11.019000     0.036800      0.017500
# 50%        0.581000     0.658000    -7.709000     0.050900      0.181000
# 75%        0.710000     0.836000    -5.561000     0.095650      0.646000
# max        0.979000     0.999000     4.140000     0.960000      0.996000
#
#        instrumentalness     liveness      valence        tempo   duration_ms
# count       6383.000000  6383.000000  6383.000000  6383.000000  6.383000e+03
# mean           0.226171     0.182984     0.499290   121.901470  2.453298e+05
# std            0.354547     0.148848     0.272633    30.167533  1.128361e+05
# min            0.000000     0.010900     0.000000     0.000000  2.956000e+04
# 25%            0.000000     0.093300     0.275000    98.029000  1.838065e+05
# 50%            0.000547     0.122000     0.499000   120.039000  2.236360e+05
# 75%            0.449500     0.231000     0.729000   140.062500  2.775270e+05
# max            0.998000     0.987000     0.989000   214.663000  3.652000e+06

# %%
scaler = StandardScaler()
scaler.fit(first_db)
first_db_scaled = scaler.transform(first_db)
first_db_scaled_df = pd.DataFrame(first_db_scaled, columns = first_db.columns)
display(first_db.head())
print()
display(first_db_scaled_df.head())
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.865   0.665    -6.289        0.073       0.04530
# 1         0.801   0.910    -6.566        0.225       0.00239
# 2         0.644   0.846    -5.443        0.275       0.12400
# 3         0.802   0.787    -6.009        0.206       0.00127
# 4         0.872   0.723    -5.968        0.247       0.02930
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.2240    0.331  111.113       268827
# 1          0.000891    0.0737    0.805   87.277       278387
# 2          0.000000    0.3530    0.503   79.182       301600
# 3          0.000181    0.0763    0.806   90.189       296907
# 4          0.000000    0.3270    0.843   93.279       307773
#    danceability    energy  loudness  speechiness  acousticness  \
# 0      1.560883  0.182830  0.503618    -0.172217     -0.827105
# 1      1.231298  1.114882  0.455325     1.209082     -0.949774
# 2      0.422786  0.871407  0.651112     1.663457     -0.602123
# 3      1.236448  0.646954  0.552434     1.036420     -0.952975
# 4      1.596931  0.403479  0.559582     1.409007     -0.872845
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.637965  0.275575 -0.617324 -0.357647     0.208258
# 1         -0.635452 -0.734259  1.121412 -1.147829     0.292989
# 2         -0.637965  1.142298  0.013610 -1.416185     0.498728
# 3         -0.637454 -0.716791  1.125080 -1.051294     0.457134
# 4         -0.637965  0.967610  1.260805 -0.948858     0.553440

# %%
first_db.describe()
# Out:
#        danceability        energy      loudness   speechiness  acousticness  \
# count  6.383000e+03  6.383000e+03  6.383000e+03  6.383000e+03  6.383000e+03
# mean   8.345371e-17 -6.649511e-17  4.539252e-17  1.473833e-16 -3.092553e-17
# std    1.000078e+00  1.000078e+00  1.000078e+00  1.000078e+00  1.000078e+00
# min   -2.893661e+00 -2.346949e+00 -6.606271e+00 -8.356044e-01 -9.566030e-01
# 25%   -6.638142e-01 -6.465066e-01 -3.210251e-01 -5.011846e-01 -9.065782e-01
# 50%    9.835052e-02  1.561996e-01  2.560508e-01 -3.730509e-01 -4.391756e-01
# 75%    7.626698e-01  8.333641e-01  6.305400e-01  3.361455e-02  8.901345e-01
# max    2.147956e+00  1.453464e+00  2.321843e+00  7.888392e+00  1.890691e+00
#
#        instrumentalness      liveness       valence         tempo  \
# count      6.383000e+03  6.383000e+03  6.383000e+03  6.383000e+03
# mean       3.267357e-16 -7.783563e-18 -1.145793e-18 -3.433029e-18
# std        1.000078e+00  1.000078e+00  1.000078e+00  1.000078e+00
# min       -6.379648e-01 -1.156199e+00 -1.831504e+00 -4.041133e+00
# 25%       -6.379648e-01 -6.025711e-01 -8.227441e-01 -7.913919e-01
# 50%       -6.364218e-01 -4.097419e-01 -1.062950e-03 -6.174240e-02
# 75%        6.299502e-01  3.226061e-01  8.426275e-01  6.020530e-01
# max        2.177117e+00  5.402010e+00  1.796365e+00  3.075120e+00
#
#         duration_ms
# count  6.383000e+03
# mean   2.453298e+05
# std    1.128361e+05
# min    2.956000e+04
# 25%    1.838065e+05
# 50%    2.236360e+05
# 75%    2.775270e+05
# max    3.652000e+06

# %% [markdown]
# # save the scaler for future
#         use for the new user input song. save it using pickle

# %%
with open("Model/scaler.pickle", "wb") as f:
    pickle.dump(scaler,f)

# %% [markdown]
# # choosing the number of clusters
# # fitting k means cluster
# # build the elbow graph to find the best k

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(first_db)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# ## Silouhette

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(first_db_scaled_df)
    
    filename = "Model/kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(first_db_scaled_df, kmeans.predict(first_db_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model = KMeans(3, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
visualizer.fit(first_db_scaled_df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 6383 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# # use the model with the best k
#     to assign every observation in your data frame to its cluster number ( adding cluster columns to the pandas data frame) using model.predict

# %%
kmeans = KMeans(n_clusters=6, random_state=1234)
kmeans.fit(first_db_scaled_df)
# Out:
# KMeans(n_clusters=6, random_state=1234)

# %%
# assign a cluster to each example
labels = kmeans.predict(first_db_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(first_db.to_numpy()[row_ix, 1], first_db.to_numpy()[row_ix, 3])
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(first_db_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    2320
# 1    1197
# 2     608
# 3    1568
# 4     631
# 5      59
# dtype: int64

# %%
#first_db_df = pd.DataFrame(first_db)
first_db["cluster"] = clusters
first_db
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.865   0.665    -6.289       0.0730      0.045300
# 1            0.801   0.910    -6.566       0.2250      0.002390
# 2            0.644   0.846    -5.443       0.2750      0.124000
# 3            0.802   0.787    -6.009       0.2060      0.001270
# 4            0.872   0.723    -5.968       0.2470      0.029300
# ...            ...     ...       ...          ...           ...
# 6378         0.791   0.591    -9.185       0.0478      0.017200
# 6379         0.655   0.794    -5.872       0.2500      0.082000
# 6380         0.757   0.920    -7.697       0.0385      0.000531
# 6381         0.826   0.900    -7.707       0.0697      0.066600
# 6382         0.745   0.853    -8.154       0.0407      0.003340
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 0             0.000000    0.2240    0.331  111.113       268827        0
# 1             0.000891    0.0737    0.805   87.277       278387        0
# 2             0.000000    0.3530    0.503   79.182       301600        2
# 3             0.000181    0.0763    0.806   90.189       296907        0
# 4             0.000000    0.3270    0.843   93.279       307773        0
# ...                ...       ...      ...      ...          ...      ...
# 6378          0.879000    0.1310    0.683  133.974       428606        0
# 6379          0.079100    0.0457    0.667  187.007       184939        0
# 6380          0.751000    0.0956    0.955  126.001       327304        0
# 6381          0.275000    0.6790    0.925  120.980       306641        2
# 6382          0.403000    0.1350    0.466  124.011       254091        0
#
# [6383 rows x 11 columns]

# %% [markdown]
# ## save the model with the best k
#         as your final model using pickle.

# %%
with open("Model/kmeans_6.pickle", "wb") as f:
    pickle.dump(kmeans,f)

# %% [markdown]
# # Add the id column again

# %%
final_rec= pd.concat([first_db,first_db_id],axis=1)

# %%
final_rec
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.865   0.665    -6.289       0.0730      0.045300
# 1            0.801   0.910    -6.566       0.2250      0.002390
# 2            0.644   0.846    -5.443       0.2750      0.124000
# 3            0.802   0.787    -6.009       0.2060      0.001270
# 4            0.872   0.723    -5.968       0.2470      0.029300
# ...            ...     ...       ...          ...           ...
# 6378         0.791   0.591    -9.185       0.0478      0.017200
# 6379         0.655   0.794    -5.872       0.2500      0.082000
# 6380         0.757   0.920    -7.697       0.0385      0.000531
# 6381         0.826   0.900    -7.707       0.0697      0.066600
# 6382         0.745   0.853    -8.154       0.0407      0.003340
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster  \
# 0             0.000000    0.2240    0.331  111.113       268827        0
# 1             0.000891    0.0737    0.805   87.277       278387        0
# 2             0.000000    0.3530    0.503   79.182       301600        2
# 3             0.000181    0.0763    0.806   90.189       296907        0
# 4             0.000000    0.3270    0.843   93.279       307773        0
# ...                ...       ...      ...      ...          ...      ...
# 6378          0.879000    0.1310    0.683  133.974       428606        0
# 6379          0.079100    0.0457    0.667  187.007       184939        0
# 6380          0.751000    0.0956    0.955  126.001       327304        0
# 6381          0.275000    0.6790    0.925  120.980       306641        2
# 6382          0.403000    0.1350    0.466  124.011       254091        0
#
#                           id
# 0     1ofhfV90EnYhEr7Un2fWiv
# 1     5g9lS8deSIxItFBmZRC4vN
# 2     1qZqFtSINOOmjYH1UE9805
# 3     7sKt5Y2zJpYw78iAxndB8y
# 4     4VQNCzfZ3MdHEwwErNXpBo
# ...                      ...
# 6378  4LWiFuehm2uY3GK8q8sduT
# 6379  3cCLvbMCHMgX7DLXPr1ALv
# 6380  2MumLWIryjcBG1eRYcRh6I
# 6381  5z0J0ztN5QG0UTRv3wSZQK
# 6382  6k5dL3jGlbliaIQRqkAGcU
#
# [6383 rows x 12 columns]

# %%
final_rec.to_csv("db/first_try_6000.csv",index=False)
