# %% [markdown]
# # Connect to Spotify API

# %%
import spotipy

# %%
import json

# %%
import pprint

# %%
import pandas as pd

# %%
import config

# %%
from bs4 import BeautifulSoup as bs
import sys
import requests
import pandas as pd

# %%
from spotipy.oauth2 import SpotifyClientCredentials
sp= spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,client_secret=config.client_secret))

# %% [markdown]
# # Helpful tricks & tips
#
# ## Understanding Json
# 1. Understanding the hierachy of a JSON can make you mad. Therefore you can cosider using some online pages where you can paste your JSON file and see the "tree" structure of the file.
#
# https://codebeautify.org/jsonviewer
#
# 2. So, copy the json output from the query and paste it on the website's left panel. On the right panel you will be able to see the hierachy of the json file.
#
#
# ## Using pprint
#
# for better showing the json file

# %% [markdown]
# # First try building df with one little playlist
#
# ## Choose playlist

# %%
playlist = sp.user_playlist_tracks("spotify","2RHNBm388mdIGQyH3ZGkaY",market="DE")

# Personal public playlist from my spotify account 
# playlist called "villian era unlocked"
# username: familie.oeljeklaus

# %%
playlist["items"][0]["track"].keys() #all keys in items>track
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
playlist["items"][0]["track"]["id"] #id from first song in the playlist
# Out:
# '6nzXkCBOhb2mxctNihOqbb'

# %%
len(playlist["items"]) #length of playlist
# Out:
# 26

# %%
playlist["total"] #total numbers in the playlist
# Out:
# 26

# %% [markdown]
# ## Extract songs of the playlis
#
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
# Function to get all tracks from a playlist into a list 
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
songs=get_playlist_tracks("familie.oeljeklaus","2RHNBm388mdIGQyH3ZGkaY")

# %%
songs
# Out:
# [{'added_at': '2022-05-31T22:55:10Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0QJIPDAEDILuo8AIq3pMuU'},
#       'href': 'https://api.spotify.com/v1/artists/0QJIPDAEDILuo8AIq3pMuU',
#       'id': '0QJIPDAEDILuo8AIq3pMuU',
#       'name': 'M.I.A.',
#       'type': 'artist',
#       'uri': 'spotify:artist:0QJIPDAEDILuo8AIq3pMuU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3dAxXNscIj0p53lBMEziYR'},
#     'href': 'https://api.spotify.com/v1/albums/3dAxXNscIj0p53lBMEziYR',
#     'id': '3dAxXNscIj0p53lBMEziYR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733d6fa293f49903ed38fbe0de',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023d6fa293f49903ed38fbe0de',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513d6fa293f49903ed38fbe0de',
#       'width': 64}],
#     'name': 'Matangi',
#     'release_date': '2013-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3dAxXNscIj0p53lBMEziYR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0QJIPDAEDILuo8AIq3pMuU'},
#      'href': 'https://api.spotify.com/v1/artists/0QJIPDAEDILuo8AIq3pMuU',
#      'id': '0QJIPDAEDILuo8AIq3pMuU',
#      'name': 'M.I.A.',
#      'type': 'artist',
#      'uri': 'spotify:artist:0QJIPDAEDILuo8AIq3pMuU'}],
#    'disc_number': 1,
#    'duration_ms': 227520,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG11200143'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6nzXkCBOhb2mxctNihOqbb'},
#    'href': 'https://api.spotify.com/v1/tracks/6nzXkCBOhb2mxctNihOqbb',
#    'id': '6nzXkCBOhb2mxctNihOqbb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bad Girls',
#    'popularity': 76,
#    'preview_url': None,
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:6nzXkCBOhb2mxctNihOqbb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:09:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yb46jwm7gqbZXVXZQ8Z1e'},
#       'href': 'https://api.spotify.com/v1/artists/0yb46jwm7gqbZXVXZQ8Z1e',
#       'id': '0yb46jwm7gqbZXVXZQ8Z1e',
#       'name': 'Bishop Briggs',
#       'type': 'artist',
#       'uri': 'spotify:artist:0yb46jwm7gqbZXVXZQ8Z1e'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1TTxcgs3zEngN0EB56yXzY'},
#     'href': 'https://api.spotify.com/v1/albums/1TTxcgs3zEngN0EB56yXzY',
#     'id': '1TTxcgs3zEngN0EB56yXzY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738cae5034066af45cdfbc4266',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028cae5034066af45cdfbc4266',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518cae5034066af45cdfbc4266',
#       'width': 64}],
#     'name': 'Church Of Scars',
#     'release_date': '2018-04-20',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1TTxcgs3zEngN0EB56yXzY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yb46jwm7gqbZXVXZQ8Z1e'},
#      'href': 'https://api.spotify.com/v1/artists/0yb46jwm7gqbZXVXZQ8Z1e',
#      'id': '0yb46jwm7gqbZXVXZQ8Z1e',
#      'name': 'Bishop Briggs',
#      'type': 'artist',
#      'uri': 'spotify:artist:0yb46jwm7gqbZXVXZQ8Z1e'}],
#    'disc_number': 1,
#    'duration_ms': 216133,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCACL1648391'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3mRLHiSHYtC8Hk7bzZdUs1'},
#    'href': 'https://api.spotify.com/v1/tracks/3mRLHiSHYtC8Hk7bzZdUs1',
#    'id': '3mRLHiSHYtC8Hk7bzZdUs1',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'River',
#    'popularity': 74,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3mRLHiSHYtC8Hk7bzZdUs1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:11:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oWOHAOyBUn6aJlKIPJK9r'},
#       'href': 'https://api.spotify.com/v1/artists/6oWOHAOyBUn6aJlKIPJK9r',
#       'id': '6oWOHAOyBUn6aJlKIPJK9r',
#       'name': 'Leah Kate',
#       'type': 'artist',
#       'uri': 'spotify:artist:6oWOHAOyBUn6aJlKIPJK9r'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6OYKLdkagNi7b1cANWVAMg'},
#     'href': 'https://api.spotify.com/v1/albums/6OYKLdkagNi7b1cANWVAMg',
#     'id': '6OYKLdkagNi7b1cANWVAMg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736080cf0a5f7314f586ef4d30',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026080cf0a5f7314f586ef4d30',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516080cf0a5f7314f586ef4d30',
#       'width': 64}],
#     'name': 'Fuck Up the Friendship',
#     'release_date': '2020-06-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6OYKLdkagNi7b1cANWVAMg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oWOHAOyBUn6aJlKIPJK9r'},
#      'href': 'https://api.spotify.com/v1/artists/6oWOHAOyBUn6aJlKIPJK9r',
#      'id': '6oWOHAOyBUn6aJlKIPJK9r',
#      'name': 'Leah Kate',
#      'type': 'artist',
#      'uri': 'spotify:artist:6oWOHAOyBUn6aJlKIPJK9r'}],
#    'disc_number': 1,
#    'duration_ms': 172757,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZHN32055844'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ddKUwm3UuvcMWLLAgOIcX'},
#    'href': 'https://api.spotify.com/v1/tracks/1ddKUwm3UuvcMWLLAgOIcX',
#    'id': '1ddKUwm3UuvcMWLLAgOIcX',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Fuck Up the Friendship',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2446658ad6dbd9a55f1aae5c6926d7523c063c34?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1ddKUwm3UuvcMWLLAgOIcX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:12:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jw70GZXlAI8QzWeY2bgRc'},
#       'href': 'https://api.spotify.com/v1/artists/2jw70GZXlAI8QzWeY2bgRc',
#       'id': '2jw70GZXlAI8QzWeY2bgRc',
#       'name': 'Nelly Furtado',
#       'type': 'artist',
#       'uri': 'spotify:artist:2jw70GZXlAI8QzWeY2bgRc'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2yboV2QBcVGEhcRlYuPpDT'},
#     'href': 'https://api.spotify.com/v1/albums/2yboV2QBcVGEhcRlYuPpDT',
#     'id': '2yboV2QBcVGEhcRlYuPpDT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a6f439c8957170652f9410e2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a6f439c8957170652f9410e2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a6f439c8957170652f9410e2',
#       'width': 64}],
#     'name': 'Loose',
#     'release_date': '2006-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:2yboV2QBcVGEhcRlYuPpDT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jw70GZXlAI8QzWeY2bgRc'},
#      'href': 'https://api.spotify.com/v1/artists/2jw70GZXlAI8QzWeY2bgRc',
#      'id': '2jw70GZXlAI8QzWeY2bgRc',
#      'name': 'Nelly Furtado',
#      'type': 'artist',
#      'uri': 'spotify:artist:2jw70GZXlAI8QzWeY2bgRc'}],
#    'disc_number': 1,
#    'duration_ms': 258893,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70601449'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4wH4dJgrsxONID6KS2tDQM'},
#    'href': 'https://api.spotify.com/v1/tracks/4wH4dJgrsxONID6KS2tDQM',
#    'id': '4wH4dJgrsxONID6KS2tDQM',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Maneater',
#    'popularity': 79,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4wH4dJgrsxONID6KS2tDQM'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:14:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20JZFwl6HVl6yg8a4H3ZqK'},
#       'href': 'https://api.spotify.com/v1/artists/20JZFwl6HVl6yg8a4H3ZqK',
#       'id': '20JZFwl6HVl6yg8a4H3ZqK',
#       'name': 'Panic! At The Disco',
#       'type': 'artist',
#       'uri': 'spotify:artist:20JZFwl6HVl6yg8a4H3ZqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6twKQ0EsUJHVlAr6XBylrj'},
#     'href': 'https://api.spotify.com/v1/albums/6twKQ0EsUJHVlAr6XBylrj',
#     'id': '6twKQ0EsUJHVlAr6XBylrj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27323152d9337d6c57b116ed13a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0223152d9337d6c57b116ed13a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485123152d9337d6c57b116ed13a',
#       'width': 64}],
#     'name': 'Death of a Bachelor',
#     'release_date': '2016-01-15',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6twKQ0EsUJHVlAr6XBylrj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20JZFwl6HVl6yg8a4H3ZqK'},
#      'href': 'https://api.spotify.com/v1/artists/20JZFwl6HVl6yg8a4H3ZqK',
#      'id': '20JZFwl6HVl6yg8a4H3ZqK',
#      'name': 'Panic! At The Disco',
#      'type': 'artist',
#      'uri': 'spotify:artist:20JZFwl6HVl6yg8a4H3ZqK'}],
#    'disc_number': 1,
#    'duration_ms': 208706,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21503701'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2DgdHcjWmO3qd50RzuBLgZ'},
#    'href': 'https://api.spotify.com/v1/tracks/2DgdHcjWmO3qd50RzuBLgZ',
#    'id': '2DgdHcjWmO3qd50RzuBLgZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'House of Memories',
#    'popularity': 86,
#    'preview_url': 'https://p.scdn.co/mp3-preview/617c372ea21745b87a21e4f251a62c0c723972e7?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:2DgdHcjWmO3qd50RzuBLgZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:14:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qDdxfKUpYg8wc49KIuT3b'},
#       'href': 'https://api.spotify.com/v1/artists/2qDdxfKUpYg8wc49KIuT3b',
#       'id': '2qDdxfKUpYg8wc49KIuT3b',
#       'name': 'Tommy Genesis',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qDdxfKUpYg8wc49KIuT3b'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2nkqAzbvQUWZ0p88NxrJ7s'},
#     'href': 'https://api.spotify.com/v1/albums/2nkqAzbvQUWZ0p88NxrJ7s',
#     'id': '2nkqAzbvQUWZ0p88NxrJ7s',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730ee17e1b890872a1c618f046',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020ee17e1b890872a1c618f046',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510ee17e1b890872a1c618f046',
#       'width': 64}],
#     'name': 'goldilocks x',
#     'release_date': '2021-09-10',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2nkqAzbvQUWZ0p88NxrJ7s'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qDdxfKUpYg8wc49KIuT3b'},
#      'href': 'https://api.spotify.com/v1/artists/2qDdxfKUpYg8wc49KIuT3b',
#      'id': '2qDdxfKUpYg8wc49KIuT3b',
#      'name': 'Tommy Genesis',
#      'type': 'artist',
#      'uri': 'spotify:artist:2qDdxfKUpYg8wc49KIuT3b'}],
#    'disc_number': 1,
#    'duration_ms': 178599,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QM6P42178544'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5kcERXTIoNbkBjb6o4vYBf'},
#    'href': 'https://api.spotify.com/v1/tracks/5kcERXTIoNbkBjb6o4vYBf',
#    'id': '5kcERXTIoNbkBjb6o4vYBf',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'a woman is a god',
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3d29ceb9d48e9cd3198db81174fb452a12f88676?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5kcERXTIoNbkBjb6o4vYBf'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:15:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#       'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#       'id': '12Chz98pHFMPJEknJQMWvI',
#       'name': 'Muse',
#       'type': 'artist',
#       'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0eFHYz8NmK75zSplL5qlfM'},
#     'href': 'https://api.spotify.com/v1/albums/0eFHYz8NmK75zSplL5qlfM',
#     'id': '0eFHYz8NmK75zSplL5qlfM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b6d4566db0d12894a1a3b7a2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b6d4566db0d12894a1a3b7a2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b6d4566db0d12894a1a3b7a2',
#       'width': 64}],
#     'name': 'The Resistance',
#     'release_date': '2009-09-10',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0eFHYz8NmK75zSplL5qlfM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#      'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#      'id': '12Chz98pHFMPJEknJQMWvI',
#      'name': 'Muse',
#      'type': 'artist',
#      'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#    'disc_number': 1,
#    'duration_ms': 304840,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAHT0900320'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4VqPOruhp5EdPBeR92t6lQ'},
#    'href': 'https://api.spotify.com/v1/tracks/4VqPOruhp5EdPBeR92t6lQ',
#    'id': '4VqPOruhp5EdPBeR92t6lQ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Uprising',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/904176ea758e40523f23d0542cfe66423c7caad4?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4VqPOruhp5EdPBeR92t6lQ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:16:26Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#       'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#       'id': '0pCNk4D3E2xtszsm6hMsWr',
#       'name': 'K.Flay',
#       'type': 'artist',
#       'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4QwcXvqLh5Yj35wBt2DnTr'},
#     'href': 'https://api.spotify.com/v1/albums/4QwcXvqLh5Yj35wBt2DnTr',
#     'id': '4QwcXvqLh5Yj35wBt2DnTr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273be9f834ad14e0d95a35a6981',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02be9f834ad14e0d95a35a6981',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851be9f834ad14e0d95a35a6981',
#       'width': 64}],
#     'name': 'Every Where Is Some Where',
#     'release_date': '2017-04-07',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4QwcXvqLh5Yj35wBt2DnTr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#      'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#      'id': '0pCNk4D3E2xtszsm6hMsWr',
#      'name': 'K.Flay',
#      'type': 'artist',
#      'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'}],
#    'disc_number': 1,
#    'duration_ms': 231600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71701789'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1qwno7xb5mJe71xtMS6jl2'},
#    'href': 'https://api.spotify.com/v1/tracks/1qwno7xb5mJe71xtMS6jl2',
#    'id': '1qwno7xb5mJe71xtMS6jl2',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'High Enough',
#    'popularity': 75,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:1qwno7xb5mJe71xtMS6jl2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:16:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7crPfGd2k81ekOoSqQKWWz'},
#       'href': 'https://api.spotify.com/v1/artists/7crPfGd2k81ekOoSqQKWWz',
#       'id': '7crPfGd2k81ekOoSqQKWWz',
#       'name': 'Stevie Nicks',
#       'type': 'artist',
#       'uri': 'spotify:artist:7crPfGd2k81ekOoSqQKWWz'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3S404OgKoVQSJ3xXrDVlp8'},
#     'href': 'https://api.spotify.com/v1/albums/3S404OgKoVQSJ3xXrDVlp8',
#     'id': '3S404OgKoVQSJ3xXrDVlp8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730c5127071182a8dd9afcdcf8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020c5127071182a8dd9afcdcf8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510c5127071182a8dd9afcdcf8',
#       'width': 64}],
#     'name': 'Bella Donna (Deluxe Edition)',
#     'release_date': '2016-11-04',
#     'release_date_precision': 'day',
#     'total_tracks': 35,
#     'type': 'album',
#     'uri': 'spotify:album:3S404OgKoVQSJ3xXrDVlp8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7crPfGd2k81ekOoSqQKWWz'},
#      'href': 'https://api.spotify.com/v1/artists/7crPfGd2k81ekOoSqQKWWz',
#      'id': '7crPfGd2k81ekOoSqQKWWz',
#      'name': 'Stevie Nicks',
#      'type': 'artist',
#      'uri': 'spotify:artist:7crPfGd2k81ekOoSqQKWWz'}],
#    'disc_number': 1,
#    'duration_ms': 329413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRH11604198'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5LNiqEqpDc8TuqPy79kDBu'},
#    'href': 'https://api.spotify.com/v1/tracks/5LNiqEqpDc8TuqPy79kDBu',
#    'id': '5LNiqEqpDc8TuqPy79kDBu',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Edge of Seventeen - 2016 Remaster',
#    'popularity': 61,
#    'preview_url': 'https://p.scdn.co/mp3-preview/abb0fd1b61b63ce4023c8f6dd26f5381d1ce5c42?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5LNiqEqpDc8TuqPy79kDBu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:17:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2W8yFh0Ga6Yf3jiayVxwkE'},
#       'href': 'https://api.spotify.com/v1/artists/2W8yFh0Ga6Yf3jiayVxwkE',
#       'id': '2W8yFh0Ga6Yf3jiayVxwkE',
#       'name': 'Dove Cameron',
#       'type': 'artist',
#       'uri': 'spotify:artist:2W8yFh0Ga6Yf3jiayVxwkE'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4jUfPmvZGiRRJwULbfk1dc'},
#     'href': 'https://api.spotify.com/v1/albums/4jUfPmvZGiRRJwULbfk1dc',
#     'id': '4jUfPmvZGiRRJwULbfk1dc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730397f50cb9dc5393db5d08bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020397f50cb9dc5393db5d08bc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510397f50cb9dc5393db5d08bc',
#       'width': 64}],
#     'name': 'Boyfriend',
#     'release_date': '2022-02-11',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4jUfPmvZGiRRJwULbfk1dc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2W8yFh0Ga6Yf3jiayVxwkE'},
#      'href': 'https://api.spotify.com/v1/artists/2W8yFh0Ga6Yf3jiayVxwkE',
#      'id': '2W8yFh0Ga6Yf3jiayVxwkE',
#      'name': 'Dove Cameron',
#      'type': 'artist',
#      'uri': 'spotify:artist:2W8yFh0Ga6Yf3jiayVxwkE'}],
#    'disc_number': 1,
#    'duration_ms': 153000,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USQX92200693'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/59CfNbkERJ3NoTXDvoURjj'},
#    'href': 'https://api.spotify.com/v1/tracks/59CfNbkERJ3NoTXDvoURjj',
#    'id': '59CfNbkERJ3NoTXDvoURjj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Boyfriend',
#    'popularity': 86,
#    'preview_url': 'https://p.scdn.co/mp3-preview/53120317c1fc5576aa178f37ddfa991f6eabf0d6?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:59CfNbkERJ3NoTXDvoURjj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:17:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44TGR1CzjKBxSHsSEy7bi9'},
#       'href': 'https://api.spotify.com/v1/artists/44TGR1CzjKBxSHsSEy7bi9',
#       'id': '44TGR1CzjKBxSHsSEy7bi9',
#       'name': 'Woodkid',
#       'type': 'artist',
#       'uri': 'spotify:artist:44TGR1CzjKBxSHsSEy7bi9'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7oRzNo0PkoRJlvI9Eocyf2'},
#     'href': 'https://api.spotify.com/v1/albums/7oRzNo0PkoRJlvI9Eocyf2',
#     'id': '7oRzNo0PkoRJlvI9Eocyf2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273216fa486e2c3e899cacfe6bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02216fa486e2c3e899cacfe6bf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851216fa486e2c3e899cacfe6bf',
#       'width': 64}],
#     'name': 'The Golden Age',
#     'release_date': '2013-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:7oRzNo0PkoRJlvI9Eocyf2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44TGR1CzjKBxSHsSEy7bi9'},
#      'href': 'https://api.spotify.com/v1/artists/44TGR1CzjKBxSHsSEy7bi9',
#      'id': '44TGR1CzjKBxSHsSEy7bi9',
#      'name': 'Woodkid',
#      'type': 'artist',
#      'uri': 'spotify:artist:44TGR1CzjKBxSHsSEy7bi9'}],
#    'disc_number': 1,
#    'duration_ms': 213266,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR4DI1200110'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0boS4e6uXwp3zAvz1mLxZS'},
#    'href': 'https://api.spotify.com/v1/tracks/0boS4e6uXwp3zAvz1mLxZS',
#    'id': '0boS4e6uXwp3zAvz1mLxZS',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Run Boy Run',
#    'popularity': 71,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0boS4e6uXwp3zAvz1mLxZS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:18:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#       'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#       'id': '6Q192DXotxtaysaqNPy5yR',
#       'name': 'Amy Winehouse',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/097eYvf9NKjFnv4xA9s2oV'},
#     'href': 'https://api.spotify.com/v1/albums/097eYvf9NKjFnv4xA9s2oV',
#     'id': '097eYvf9NKjFnv4xA9s2oV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738f52f321140e4a76ea720c52',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028f52f321140e4a76ea720c52',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518f52f321140e4a76ea720c52',
#       'width': 64}],
#     'name': 'Back To Black',
#     'release_date': '2006-10-27',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:097eYvf9NKjFnv4xA9s2oV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#      'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#      'id': '6Q192DXotxtaysaqNPy5yR',
#      'name': 'Amy Winehouse',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#    'disc_number': 1,
#    'duration_ms': 256946,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM70603488'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4zQuwW24dweWcaX0fEJkP2'},
#    'href': 'https://api.spotify.com/v1/tracks/4zQuwW24dweWcaX0fEJkP2',
#    'id': '4zQuwW24dweWcaX0fEJkP2',
#    'is_local': False,
#    'is_playable': True,
#    'name': "You Know I'm No Good",
#    'popularity': 64,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4zQuwW24dweWcaX0fEJkP2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:19:24Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eXZu6O7nAUA5z6vLV8NKI'},
#       'href': 'https://api.spotify.com/v1/artists/6eXZu6O7nAUA5z6vLV8NKI',
#       'id': '6eXZu6O7nAUA5z6vLV8NKI',
#       'name': 'Little Simz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eXZu6O7nAUA5z6vLV8NKI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Wwm4xg2748zhYuzDRFTgY'},
#     'href': 'https://api.spotify.com/v1/albums/4Wwm4xg2748zhYuzDRFTgY',
#     'id': '4Wwm4xg2748zhYuzDRFTgY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731c54fc953531d5da04232deb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021c54fc953531d5da04232deb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511c54fc953531d5da04232deb',
#       'width': 64}],
#     'name': 'GREY Area',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4Wwm4xg2748zhYuzDRFTgY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eXZu6O7nAUA5z6vLV8NKI'},
#      'href': 'https://api.spotify.com/v1/artists/6eXZu6O7nAUA5z6vLV8NKI',
#      'id': '6eXZu6O7nAUA5z6vLV8NKI',
#      'name': 'Little Simz',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eXZu6O7nAUA5z6vLV8NKI'}],
#    'disc_number': 1,
#    'duration_ms': 154749,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBWWP1804476'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3A0ITFj6kbb9CggwtPe55f'},
#    'href': 'https://api.spotify.com/v1/tracks/3A0ITFj6kbb9CggwtPe55f',
#    'id': '3A0ITFj6kbb9CggwtPe55f',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Venom',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/22408603a747c3d02dd756fc37e6a00520554e89?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:3A0ITFj6kbb9CggwtPe55f'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:20:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#       'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#       'id': '3ICflSq6ZgYAIrm2CTkfVP',
#       'name': 'The Animals',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1v4O55JGou3T0Vlj06fdXz'},
#     'href': 'https://api.spotify.com/v1/albums/1v4O55JGou3T0Vlj06fdXz',
#     'id': '1v4O55JGou3T0Vlj06fdXz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273015c484a7aca592df1a77828',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02015c484a7aca592df1a77828',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851015c484a7aca592df1a77828',
#       'width': 64}],
#     'name': 'The Singles Plus',
#     'release_date': '1987-10-19',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:1v4O55JGou3T0Vlj06fdXz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#      'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#      'id': '3ICflSq6ZgYAIrm2CTkfVP',
#      'name': 'The Animals',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#    'disc_number': 1,
#    'duration_ms': 269906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE6400209'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4mn2kNTqiGLwaUR8JdhJ1l'},
#    'href': 'https://api.spotify.com/v1/tracks/4mn2kNTqiGLwaUR8JdhJ1l',
#    'id': '4mn2kNTqiGLwaUR8JdhJ1l',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7BY005dacJkbO6EPiOh2wb'},
#     'href': 'https://api.spotify.com/v1/tracks/7BY005dacJkbO6EPiOh2wb',
#     'id': '7BY005dacJkbO6EPiOh2wb',
#     'type': 'track',
#     'uri': 'spotify:track:7BY005dacJkbO6EPiOh2wb'},
#    'name': 'House of the Rising Sun',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3f5ed575e67b66ef0c40ac1c52b3c11e022d8499?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4mn2kNTqiGLwaUR8JdhJ1l'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:21:14Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#     'href': 'https://api.spotify.com/v1/albums/78bpIziExqiI9qztvNFlQu',
#     'id': '78bpIziExqiI9qztvNFlQu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734ae1c4c5c45aabe565499163',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024ae1c4c5c45aabe565499163',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514ae1c4c5c45aabe565499163',
#       'width': 64}],
#     'name': 'AM',
#     'release_date': '2013-09-09',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:78bpIziExqiI9qztvNFlQu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#      'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#      'id': '7Ln80lUS6He07XvHI8qqHH',
#      'name': 'Arctic Monkeys',
#      'type': 'artist',
#      'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#    'disc_number': 1,
#    'duration_ms': 272394,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEL1300362'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5FVd6KXrgO9B3JPmC8OPst'},
#    'href': 'https://api.spotify.com/v1/tracks/5FVd6KXrgO9B3JPmC8OPst',
#    'id': '5FVd6KXrgO9B3JPmC8OPst',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Do I Wanna Know?',
#    'popularity': 87,
#    'preview_url': 'https://p.scdn.co/mp3-preview/18d8be17343d3ef580e93a5fff47c9b58870a31a?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5FVd6KXrgO9B3JPmC8OPst'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:21:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5RCWMaArEntbkeWYVxCiFW'},
#       'href': 'https://api.spotify.com/v1/artists/5RCWMaArEntbkeWYVxCiFW',
#       'id': '5RCWMaArEntbkeWYVxCiFW',
#       'name': 'Everybody Loves an Outlaw',
#       'type': 'artist',
#       'uri': 'spotify:artist:5RCWMaArEntbkeWYVxCiFW'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/160pzqIuixGY7qegAnQCHY'},
#     'href': 'https://api.spotify.com/v1/albums/160pzqIuixGY7qegAnQCHY',
#     'id': '160pzqIuixGY7qegAnQCHY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734616b06cfa2a597788e0ef28',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024616b06cfa2a597788e0ef28',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514616b06cfa2a597788e0ef28',
#       'width': 64}],
#     'name': 'I See Red',
#     'release_date': '2018-10-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:160pzqIuixGY7qegAnQCHY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5RCWMaArEntbkeWYVxCiFW'},
#      'href': 'https://api.spotify.com/v1/artists/5RCWMaArEntbkeWYVxCiFW',
#      'id': '5RCWMaArEntbkeWYVxCiFW',
#      'name': 'Everybody Loves an Outlaw',
#      'type': 'artist',
#      'uri': 'spotify:artist:5RCWMaArEntbkeWYVxCiFW'}],
#    'disc_number': 1,
#    'duration_ms': 230613,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQX92003330'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5MAK1nd8R6PWnle1Q1WJvh'},
#    'href': 'https://api.spotify.com/v1/tracks/5MAK1nd8R6PWnle1Q1WJvh',
#    'id': '5MAK1nd8R6PWnle1Q1WJvh',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I See Red',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/30a7324491b81b206769150a797445216f5e54df?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5MAK1nd8R6PWnle1Q1WJvh'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:23:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1JhiIIXT9DWqEU3BYFZwGA'},
#       'href': 'https://api.spotify.com/v1/artists/1JhiIIXT9DWqEU3BYFZwGA',
#       'id': '1JhiIIXT9DWqEU3BYFZwGA',
#       'name': 'MOTHICA',
#       'type': 'artist',
#       'uri': 'spotify:artist:1JhiIIXT9DWqEU3BYFZwGA'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Ctdbwmab7JKb5ZB8nbT0q'},
#     'href': 'https://api.spotify.com/v1/albums/2Ctdbwmab7JKb5ZB8nbT0q',
#     'id': '2Ctdbwmab7JKb5ZB8nbT0q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273884fc0c3b02537ebf36bd5ec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02884fc0c3b02537ebf36bd5ec',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851884fc0c3b02537ebf36bd5ec',
#       'width': 64}],
#     'name': 'CASUALTY',
#     'release_date': '2022-01-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2Ctdbwmab7JKb5ZB8nbT0q'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1JhiIIXT9DWqEU3BYFZwGA'},
#      'href': 'https://api.spotify.com/v1/artists/1JhiIIXT9DWqEU3BYFZwGA',
#      'id': '1JhiIIXT9DWqEU3BYFZwGA',
#      'name': 'MOTHICA',
#      'type': 'artist',
#      'uri': 'spotify:artist:1JhiIIXT9DWqEU3BYFZwGA'}],
#    'disc_number': 1,
#    'duration_ms': 158081,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMRSZ2200074'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3OWxpc6Zguzep0XKWGxDyc'},
#    'href': 'https://api.spotify.com/v1/tracks/3OWxpc6Zguzep0XKWGxDyc',
#    'id': '3OWxpc6Zguzep0XKWGxDyc',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'CASUALTY',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0d1aef86565e846910e4366f1f99bd921b17bbfe?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3OWxpc6Zguzep0XKWGxDyc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:24:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2O8CMGDnzYHpcZOSNVoLdQ'},
#       'href': 'https://api.spotify.com/v1/artists/2O8CMGDnzYHpcZOSNVoLdQ',
#       'id': '2O8CMGDnzYHpcZOSNVoLdQ',
#       'name': 'ADONA',
#       'type': 'artist',
#       'uri': 'spotify:artist:2O8CMGDnzYHpcZOSNVoLdQ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5CY5RFnrmyGMHcp3EWhhFM'},
#     'href': 'https://api.spotify.com/v1/albums/5CY5RFnrmyGMHcp3EWhhFM',
#     'id': '5CY5RFnrmyGMHcp3EWhhFM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cab20676aeeb989d31fb1def',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cab20676aeeb989d31fb1def',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cab20676aeeb989d31fb1def',
#       'width': 64}],
#     'name': "I've Got A Bad Side",
#     'release_date': '2022-05-27',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5CY5RFnrmyGMHcp3EWhhFM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2O8CMGDnzYHpcZOSNVoLdQ'},
#      'href': 'https://api.spotify.com/v1/artists/2O8CMGDnzYHpcZOSNVoLdQ',
#      'id': '2O8CMGDnzYHpcZOSNVoLdQ',
#      'name': 'ADONA',
#      'type': 'artist',
#      'uri': 'spotify:artist:2O8CMGDnzYHpcZOSNVoLdQ'}],
#    'disc_number': 1,
#    'duration_ms': 168034,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USXB22200015'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3zaSRGFPFnNKY42TUjoGwM'},
#    'href': 'https://api.spotify.com/v1/tracks/3zaSRGFPFnNKY42TUjoGwM',
#    'id': '3zaSRGFPFnNKY42TUjoGwM',
#    'is_local': False,
#    'is_playable': True,
#    'name': "I've Got A Bad Side",
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/669973182531517ef2afddcacd2fb310aef7b2a9?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3zaSRGFPFnNKY42TUjoGwM'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:25:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4PR77KtW5drJXCsqcyfuzJ'},
#       'href': 'https://api.spotify.com/v1/artists/4PR77KtW5drJXCsqcyfuzJ',
#       'id': '4PR77KtW5drJXCsqcyfuzJ',
#       'name': 'OSTON',
#       'type': 'artist',
#       'uri': 'spotify:artist:4PR77KtW5drJXCsqcyfuzJ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2SisBph5Spa2QQgye7AeRX'},
#     'href': 'https://api.spotify.com/v1/albums/2SisBph5Spa2QQgye7AeRX',
#     'id': '2SisBph5Spa2QQgye7AeRX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27399c846d88826e3fdaa2ccc29',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0299c846d88826e3fdaa2ccc29',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485199c846d88826e3fdaa2ccc29',
#       'width': 64}],
#     'name': 'Whatshisface',
#     'release_date': '2022-05-20',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:2SisBph5Spa2QQgye7AeRX'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4PR77KtW5drJXCsqcyfuzJ'},
#      'href': 'https://api.spotify.com/v1/artists/4PR77KtW5drJXCsqcyfuzJ',
#      'id': '4PR77KtW5drJXCsqcyfuzJ',
#      'name': 'OSTON',
#      'type': 'artist',
#      'uri': 'spotify:artist:4PR77KtW5drJXCsqcyfuzJ'}],
#    'disc_number': 1,
#    'duration_ms': 161840,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZNEZ2000101'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3VIpGWhJ4vFjqqGmABxMEs'},
#    'href': 'https://api.spotify.com/v1/tracks/3VIpGWhJ4vFjqqGmABxMEs',
#    'id': '3VIpGWhJ4vFjqqGmABxMEs',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Whatshisface',
#    'popularity': 54,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3VIpGWhJ4vFjqqGmABxMEs'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:25:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4S38gbKfKkEbty2YAIDIlV'},
#       'href': 'https://api.spotify.com/v1/artists/4S38gbKfKkEbty2YAIDIlV',
#       'id': '4S38gbKfKkEbty2YAIDIlV',
#       'name': 'EMELINE',
#       'type': 'artist',
# ...
#       'href': 'https://api.spotify.com/v1/artists/6oWOHAOyBUn6aJlKIPJK9r',
#       'id': '6oWOHAOyBUn6aJlKIPJK9r',
#       'name': 'Leah Kate',
#       'type': 'artist',
#       'uri': 'spotify:artist:6oWOHAOyBUn6aJlKIPJK9r'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/26hYEKjKZU1sTC4mUPpVI6'},
#     'href': 'https://api.spotify.com/v1/albums/26hYEKjKZU1sTC4mUPpVI6',
#     'id': '26hYEKjKZU1sTC4mUPpVI6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273596a9d381ffda7d97da5d702',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02596a9d381ffda7d97da5d702',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851596a9d381ffda7d97da5d702',
#       'width': 64}],
#     'name': '10 Things I Hate About You',
#     'release_date': '2022-03-23',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:26hYEKjKZU1sTC4mUPpVI6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oWOHAOyBUn6aJlKIPJK9r'},
#      'href': 'https://api.spotify.com/v1/artists/6oWOHAOyBUn6aJlKIPJK9r',
#      'id': '6oWOHAOyBUn6aJlKIPJK9r',
#      'name': 'Leah Kate',
#      'type': 'artist',
#      'uri': 'spotify:artist:6oWOHAOyBUn6aJlKIPJK9r'}],
#    'disc_number': 1,
#    'duration_ms': 157138,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZES62254244'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Jkm5kUldvIqxzI1Pa7nXH'},
#    'href': 'https://api.spotify.com/v1/tracks/6Jkm5kUldvIqxzI1Pa7nXH',
#    'id': '6Jkm5kUldvIqxzI1Pa7nXH',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1shKa7wLElW8CrbHOJk85M'},
#     'href': 'https://api.spotify.com/v1/tracks/1shKa7wLElW8CrbHOJk85M',
#     'id': '1shKa7wLElW8CrbHOJk85M',
#     'type': 'track',
#     'uri': 'spotify:track:1shKa7wLElW8CrbHOJk85M'},
#    'name': '10 Things I Hate About You',
#    'popularity': 82,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6Jkm5kUldvIqxzI1Pa7nXH'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:27:21Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4B1bjBU8CLkIBTYTRklo2u'},
#       'href': 'https://api.spotify.com/v1/artists/4B1bjBU8CLkIBTYTRklo2u',
#       'id': '4B1bjBU8CLkIBTYTRklo2u',
#       'name': 'Chloe Adams',
#       'type': 'artist',
#       'uri': 'spotify:artist:4B1bjBU8CLkIBTYTRklo2u'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0GgNNJPbQUpny8XErV9Vhw'},
#     'href': 'https://api.spotify.com/v1/albums/0GgNNJPbQUpny8XErV9Vhw',
#     'id': '0GgNNJPbQUpny8XErV9Vhw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d17de6bc3476fac4e9589a53',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d17de6bc3476fac4e9589a53',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d17de6bc3476fac4e9589a53',
#       'width': 64}],
#     'name': 'Dead To Me',
#     'release_date': '2022-02-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0GgNNJPbQUpny8XErV9Vhw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4B1bjBU8CLkIBTYTRklo2u'},
#      'href': 'https://api.spotify.com/v1/artists/4B1bjBU8CLkIBTYTRklo2u',
#      'id': '4B1bjBU8CLkIBTYTRklo2u',
#      'name': 'Chloe Adams',
#      'type': 'artist',
#      'uri': 'spotify:artist:4B1bjBU8CLkIBTYTRklo2u'}],
#    'disc_number': 1,
#    'duration_ms': 153222,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'FR10S2296153'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6tPLIurCFf9MAGYvba94ub'},
#    'href': 'https://api.spotify.com/v1/tracks/6tPLIurCFf9MAGYvba94ub',
#    'id': '6tPLIurCFf9MAGYvba94ub',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Dead To Me',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a9bd31115dbb373965dca36500517b110a4dbeda?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6tPLIurCFf9MAGYvba94ub'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:27:34Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6z4NUKuKEzIzo28BPOjVof'},
#       'href': 'https://api.spotify.com/v1/artists/6z4NUKuKEzIzo28BPOjVof',
#       'id': '6z4NUKuKEzIzo28BPOjVof',
#       'name': 'ASTON',
#       'type': 'artist',
#       'uri': 'spotify:artist:6z4NUKuKEzIzo28BPOjVof'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2S1oHdSgzillUEO1juCGaX'},
#     'href': 'https://api.spotify.com/v1/albums/2S1oHdSgzillUEO1juCGaX',
#     'id': '2S1oHdSgzillUEO1juCGaX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b74b5840ebb95fe5d37690c9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b74b5840ebb95fe5d37690c9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b74b5840ebb95fe5d37690c9',
#       'width': 64}],
#     'name': "Women Don't Owe You Sh*t",
#     'release_date': '2022-01-28',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:2S1oHdSgzillUEO1juCGaX'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6z4NUKuKEzIzo28BPOjVof'},
#      'href': 'https://api.spotify.com/v1/artists/6z4NUKuKEzIzo28BPOjVof',
#      'id': '6z4NUKuKEzIzo28BPOjVof',
#      'name': 'ASTON',
#      'type': 'artist',
#      'uri': 'spotify:artist:6z4NUKuKEzIzo28BPOjVof'}],
#    'disc_number': 1,
#    'duration_ms': 212969,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'FR10S2225678'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6HoZUmprRfFWO1CaqkiBUP'},
#    'href': 'https://api.spotify.com/v1/tracks/6HoZUmprRfFWO1CaqkiBUP',
#    'id': '6HoZUmprRfFWO1CaqkiBUP',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Women Don't Owe You Sh*t",
#    'popularity': 46,
#    'preview_url': 'https://p.scdn.co/mp3-preview/353eb9d1699980762d89db7732ee9547091eacac?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6HoZUmprRfFWO1CaqkiBUP'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-05-31T23:28:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28eWMibpUITBXZVQM0RWnL'},
#       'href': 'https://api.spotify.com/v1/artists/28eWMibpUITBXZVQM0RWnL',
#       'id': '28eWMibpUITBXZVQM0RWnL',
#       'name': 'LITO',
#       'type': 'artist',
#       'uri': 'spotify:artist:28eWMibpUITBXZVQM0RWnL'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0wun1JnzKmylaykmjfrthP'},
#       'href': 'https://api.spotify.com/v1/artists/0wun1JnzKmylaykmjfrthP',
#       'id': '0wun1JnzKmylaykmjfrthP',
#       'name': 'Heinrich',
#       'type': 'artist',
#       'uri': 'spotify:artist:0wun1JnzKmylaykmjfrthP'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1G1Tnx8wjroUqia9gdjjrD'},
#     'href': 'https://api.spotify.com/v1/albums/1G1Tnx8wjroUqia9gdjjrD',
#     'id': '1G1Tnx8wjroUqia9gdjjrD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273be2b81b641ecb0a0b9a3feb7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02be2b81b641ecb0a0b9a3feb7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851be2b81b641ecb0a0b9a3feb7',
#       'width': 64}],
#     'name': 'Rise Again',
#     'release_date': '2022-03-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1G1Tnx8wjroUqia9gdjjrD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28eWMibpUITBXZVQM0RWnL'},
#      'href': 'https://api.spotify.com/v1/artists/28eWMibpUITBXZVQM0RWnL',
#      'id': '28eWMibpUITBXZVQM0RWnL',
#      'name': 'LITO',
#      'type': 'artist',
#      'uri': 'spotify:artist:28eWMibpUITBXZVQM0RWnL'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0wun1JnzKmylaykmjfrthP'},
#      'href': 'https://api.spotify.com/v1/artists/0wun1JnzKmylaykmjfrthP',
#      'id': '0wun1JnzKmylaykmjfrthP',
#      'name': 'Heinrich',
#      'type': 'artist',
#      'uri': 'spotify:artist:0wun1JnzKmylaykmjfrthP'}],
#    'disc_number': 1,
#    'duration_ms': 197396,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEZC62257410'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2RvheiLZEgoDwiHm5BJNhi'},
#    'href': 'https://api.spotify.com/v1/tracks/2RvheiLZEgoDwiHm5BJNhi',
#    'id': '2RvheiLZEgoDwiHm5BJNhi',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Rise Again',
#    'popularity': 9,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7286ec19a489ccbf2f55c16adf40879cd7a393f4?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2RvheiLZEgoDwiHm5BJNhi'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-06-03T10:54:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28eWMibpUITBXZVQM0RWnL'},
#       'href': 'https://api.spotify.com/v1/artists/28eWMibpUITBXZVQM0RWnL',
#       'id': '28eWMibpUITBXZVQM0RWnL',
#       'name': 'LITO',
#       'type': 'artist',
#       'uri': 'spotify:artist:28eWMibpUITBXZVQM0RWnL'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0wun1JnzKmylaykmjfrthP'},
#       'href': 'https://api.spotify.com/v1/artists/0wun1JnzKmylaykmjfrthP',
#       'id': '0wun1JnzKmylaykmjfrthP',
#       'name': 'Heinrich',
#       'type': 'artist',
#       'uri': 'spotify:artist:0wun1JnzKmylaykmjfrthP'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4E8sQeajlEAg1JzUIl1O7M'},
#     'href': 'https://api.spotify.com/v1/albums/4E8sQeajlEAg1JzUIl1O7M',
#     'id': '4E8sQeajlEAg1JzUIl1O7M',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737ac01ca3023cd8890513cfe9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027ac01ca3023cd8890513cfe9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517ac01ca3023cd8890513cfe9',
#       'width': 64}],
#     'name': 'Bed Behaviour',
#     'release_date': '2022-06-03',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:4E8sQeajlEAg1JzUIl1O7M'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28eWMibpUITBXZVQM0RWnL'},
#      'href': 'https://api.spotify.com/v1/artists/28eWMibpUITBXZVQM0RWnL',
#      'id': '28eWMibpUITBXZVQM0RWnL',
#      'name': 'LITO',
#      'type': 'artist',
#      'uri': 'spotify:artist:28eWMibpUITBXZVQM0RWnL'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0wun1JnzKmylaykmjfrthP'},
#      'href': 'https://api.spotify.com/v1/artists/0wun1JnzKmylaykmjfrthP',
#      'id': '0wun1JnzKmylaykmjfrthP',
#      'name': 'Heinrich',
#      'type': 'artist',
#      'uri': 'spotify:artist:0wun1JnzKmylaykmjfrthP'}],
#    'disc_number': 1,
#    'duration_ms': 192880,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEZC62270252'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2PfPVnXTySxnmX6ljVkZKV'},
#    'href': 'https://api.spotify.com/v1/tracks/2PfPVnXTySxnmX6ljVkZKV',
#    'id': '2PfPVnXTySxnmX6ljVkZKV',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bed Behaviour',
#    'popularity': 22,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cf115349db639cd5179b767e866de39f16aaeec9?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2PfPVnXTySxnmX6ljVkZKV'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-06-22T21:30:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/familie.oeljeklaus'},
#    'href': 'https://api.spotify.com/v1/users/familie.oeljeklaus',
#    'id': 'familie.oeljeklaus',
#    'type': 'user',
#    'uri': 'spotify:user:familie.oeljeklaus'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eBTKnv4ZEpwTOq3dtYWPp'},
#       'href': 'https://api.spotify.com/v1/artists/3eBTKnv4ZEpwTOq3dtYWPp',
#       'id': '3eBTKnv4ZEpwTOq3dtYWPp',
#       'name': 'DJ 90210',
#       'type': 'artist',
#       'uri': 'spotify:artist:3eBTKnv4ZEpwTOq3dtYWPp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3apKJWwZQVoRCjzxYKrIqa'},
#     'href': 'https://api.spotify.com/v1/albums/3apKJWwZQVoRCjzxYKrIqa',
#     'id': '3apKJWwZQVoRCjzxYKrIqa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273656eccd03738d599e29a08c2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02656eccd03738d599e29a08c2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851656eccd03738d599e29a08c2',
#       'width': 64}],
#     'name': 'HI NRG Dance Vol 7',
#     'release_date': '2009',
#     'release_date_precision': 'year',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3apKJWwZQVoRCjzxYKrIqa'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eBTKnv4ZEpwTOq3dtYWPp'},
#      'href': 'https://api.spotify.com/v1/artists/3eBTKnv4ZEpwTOq3dtYWPp',
#      'id': '3eBTKnv4ZEpwTOq3dtYWPp',
#      'name': 'DJ 90210',
#      'type': 'artist',
#      'uri': 'spotify:artist:3eBTKnv4ZEpwTOq3dtYWPp'}],
#    'disc_number': 1,
#    'duration_ms': 308291,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUXN20901826'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0ZlhILQ2RLAHANZXSXZmlA'},
#    'href': 'https://api.spotify.com/v1/tracks/0ZlhILQ2RLAHANZXSXZmlA',
#    'id': '0ZlhILQ2RLAHANZXSXZmlA',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Wild Women Do',
#    'popularity': 10,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ae7e14e25e23bbfe612681f24b6a8a1e53ef8c15?cid=129479205e3b49ea852c187b95af6d35',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:0ZlhILQ2RLAHANZXSXZmlA'},
#   'video_thumbnail': {'url': None}}]

# %%
songs[24]["track"]["artists"][0]["name"]
# Out:
# 'LITO'

# %%
len(songs)
# Out:
# 26

# %% [markdown]
# ## Extracting name of the songs from the playlist

# %%
song_name=[]
for s_name in range(0,len(songs)):
    print (songs[s_name]["track"]["name"])
    song_name.append(songs[s_name]["track"]["name"])
# Out:
# Bad Girls
# River
# Fuck Up the Friendship
# Maneater
# House of Memories
# a woman is a god
# Uprising
# High Enough
# Edge of Seventeen - 2016 Remaster
# Boyfriend
# Run Boy Run
# You Know I'm No Good
# Venom
# House of the Rising Sun
# Do I Wanna Know?
# I See Red
# CASUALTY
# I've Got A Bad Side
# Whatshisface
# cinderella's dead
# 10 Things I Hate About You
# Dead To Me
# Women Don't Owe You Sh*t
# Rise Again
# Bed Behaviour
# Wild Women Do

# %%
len(song_name)
# Out:
# 26

# %%
len(song_name)
# Out:
# 26

# %% [markdown]
# ## Extracting artist name of the songs from the playlist

# %%
#songs[70]["track"]["artists"][0]["name"]

# %%
artist_name=[]
for a_name in range(0,len(songs)):
    print (songs[a_name]["track"]["artists"][0]["name"])
    artist_name.append(songs[a_name]["track"]["artists"][0]["name"])
# Out:
# M.I.A.
# Bishop Briggs
# Leah Kate
# Nelly Furtado
# Panic! At The Disco
# Tommy Genesis
# Muse
# K.Flay
# Stevie Nicks
# Dove Cameron
# Woodkid
# Amy Winehouse
# Little Simz
# The Animals
# Arctic Monkeys
# Everybody Loves an Outlaw
# MOTHICA
# ADONA
# OSTON
# EMELINE
# Leah Kate
# Chloe Adams
# ASTON
# LITO
# LITO
# DJ 90210

# %%
len(artist_name)
# Out:
# 26

# %% [markdown]
# ## Extracting audio features of the ids of the songs from playlist

# %%
list_of_audio_features=[]
for value in range(0,len(songs)):
    print (songs[value]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(songs[value]["track"]["id"])[0])
# Out:
# 6nzXkCBOhb2mxctNihOqbb
# 3mRLHiSHYtC8Hk7bzZdUs1
# 1ddKUwm3UuvcMWLLAgOIcX
# 4wH4dJgrsxONID6KS2tDQM
# 2DgdHcjWmO3qd50RzuBLgZ
# 5kcERXTIoNbkBjb6o4vYBf
# 4VqPOruhp5EdPBeR92t6lQ
# 1qwno7xb5mJe71xtMS6jl2
# 5LNiqEqpDc8TuqPy79kDBu
# 59CfNbkERJ3NoTXDvoURjj
# 0boS4e6uXwp3zAvz1mLxZS
# 4zQuwW24dweWcaX0fEJkP2
# 3A0ITFj6kbb9CggwtPe55f
# 4mn2kNTqiGLwaUR8JdhJ1l
# 5FVd6KXrgO9B3JPmC8OPst
# 5MAK1nd8R6PWnle1Q1WJvh
# 3OWxpc6Zguzep0XKWGxDyc
# 3zaSRGFPFnNKY42TUjoGwM
# 3VIpGWhJ4vFjqqGmABxMEs
# 5MWXOo8DJwgODtPGaietNz
# 6Jkm5kUldvIqxzI1Pa7nXH
# 6tPLIurCFf9MAGYvba94ub
# 6HoZUmprRfFWO1CaqkiBUP
# 2RvheiLZEgoDwiHm5BJNhi
# 2PfPVnXTySxnmX6ljVkZKV
# 0ZlhILQ2RLAHANZXSXZmlA

# %%
len(list_of_audio_features)
# Out:
# 26

# %%
list_of_audio_features
# Out:
# [{'danceability': 0.639,
#   'energy': 0.912,
#   'key': 1,
#   'loudness': -2.621,
#   'mode': 1,
#   'speechiness': 0.0615,
#   'acousticness': 0.00107,
#   'instrumentalness': 0,
#   'liveness': 0.097,
#   'valence': 0.343,
#   'tempo': 143.448,
#   'type': 'audio_features',
#   'id': '6nzXkCBOhb2mxctNihOqbb',
#   'uri': 'spotify:track:6nzXkCBOhb2mxctNihOqbb',
#   'track_href': 'https://api.spotify.com/v1/tracks/6nzXkCBOhb2mxctNihOqbb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nzXkCBOhb2mxctNihOqbb',
#   'duration_ms': 227520,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.477,
#   'key': 2,
#   'loudness': -6.737,
#   'mode': 0,
#   'speechiness': 0.0687,
#   'acousticness': 0.302,
#   'instrumentalness': 2.97e-06,
#   'liveness': 0.0579,
#   'valence': 0.545,
#   'tempo': 62.507,
#   'type': 'audio_features',
#   'id': '3mRLHiSHYtC8Hk7bzZdUs1',
#   'uri': 'spotify:track:3mRLHiSHYtC8Hk7bzZdUs1',
#   'track_href': 'https://api.spotify.com/v1/tracks/3mRLHiSHYtC8Hk7bzZdUs1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3mRLHiSHYtC8Hk7bzZdUs1',
#   'duration_ms': 216133,
#   'time_signature': 4},
#  {'danceability': 0.744,
#   'energy': 0.736,
#   'key': 1,
#   'loudness': -5.258,
#   'mode': 0,
#   'speechiness': 0.291,
#   'acousticness': 0.142,
#   'instrumentalness': 1.1e-05,
#   'liveness': 0.11,
#   'valence': 0.77,
#   'tempo': 103.993,
#   'type': 'audio_features',
#   'id': '1ddKUwm3UuvcMWLLAgOIcX',
#   'uri': 'spotify:track:1ddKUwm3UuvcMWLLAgOIcX',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ddKUwm3UuvcMWLLAgOIcX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ddKUwm3UuvcMWLLAgOIcX',
#   'duration_ms': 172758,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.777,
#   'key': 6,
#   'loudness': -4.81,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'acousticness': 0.0261,
#   'instrumentalness': 0.000358,
#   'liveness': 0.121,
#   'valence': 0.787,
#   'tempo': 132.722,
#   'type': 'audio_features',
#   'id': '4wH4dJgrsxONID6KS2tDQM',
#   'uri': 'spotify:track:4wH4dJgrsxONID6KS2tDQM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wH4dJgrsxONID6KS2tDQM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wH4dJgrsxONID6KS2tDQM',
#   'duration_ms': 258893,
#   'time_signature': 4},
#  {'danceability': 0.506,
#   'energy': 0.817,
#   'key': 11,
#   'loudness': -5.051,
#   'mode': 0,
#   'speechiness': 0.0335,
#   'acousticness': 0.00272,
#   'instrumentalness': 0,
#   'liveness': 0.0486,
#   'valence': 0.506,
#   'tempo': 109.952,
#   'type': 'audio_features',
#   'id': '2DgdHcjWmO3qd50RzuBLgZ',
#   'uri': 'spotify:track:2DgdHcjWmO3qd50RzuBLgZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2DgdHcjWmO3qd50RzuBLgZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DgdHcjWmO3qd50RzuBLgZ',
#   'duration_ms': 208707,
#   'time_signature': 4},
#  {'danceability': 0.852,
#   'energy': 0.671,
#   'key': 11,
#   'loudness': -9.251,
#   'mode': 0,
#   'speechiness': 0.0553,
#   'acousticness': 0.012,
#   'instrumentalness': 0.063,
#   'liveness': 0.103,
#   'valence': 0.886,
#   'tempo': 129.003,
#   'type': 'audio_features',
#   'id': '5kcERXTIoNbkBjb6o4vYBf',
#   'uri': 'spotify:track:5kcERXTIoNbkBjb6o4vYBf',
#   'track_href': 'https://api.spotify.com/v1/tracks/5kcERXTIoNbkBjb6o4vYBf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5kcERXTIoNbkBjb6o4vYBf',
#   'duration_ms': 178600,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.905,
#   'key': 2,
#   'loudness': -4.046,
#   'mode': 1,
#   'speechiness': 0.0775,
#   'acousticness': 0.000202,
#   'instrumentalness': 0.064,
#   'liveness': 0.117,
#   'valence': 0.411,
#   'tempo': 128.019,
#   'type': 'audio_features',
#   'id': '4VqPOruhp5EdPBeR92t6lQ',
#   'uri': 'spotify:track:4VqPOruhp5EdPBeR92t6lQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4VqPOruhp5EdPBeR92t6lQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VqPOruhp5EdPBeR92t6lQ',
#   'duration_ms': 304840,
#   'time_signature': 4},
#  {'danceability': 0.606,
#   'energy': 0.62,
#   'key': 0,
#   'loudness': -5.005,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.0301,
#   'instrumentalness': 0.0916,
#   'liveness': 0.167,
#   'valence': 0.543,
#   'tempo': 88.984,
#   'type': 'audio_features',
#   'id': '1qwno7xb5mJe71xtMS6jl2',
#   'uri': 'spotify:track:1qwno7xb5mJe71xtMS6jl2',
#   'track_href': 'https://api.spotify.com/v1/tracks/1qwno7xb5mJe71xtMS6jl2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qwno7xb5mJe71xtMS6jl2',
#   'duration_ms': 231600,
#   'time_signature': 4},
#  {'danceability': 0.591,
#   'energy': 0.804,
#   'key': 0,
#   'loudness': -7.299,
#   'mode': 1,
#   'speechiness': 0.0454,
#   'acousticness': 0.327,
#   'instrumentalness': 5.98e-06,
#   'liveness': 0.0818,
#   'valence': 0.658,
#   'tempo': 111.457,
#   'type': 'audio_features',
#   'id': '5LNiqEqpDc8TuqPy79kDBu',
#   'uri': 'spotify:track:5LNiqEqpDc8TuqPy79kDBu',
#   'track_href': 'https://api.spotify.com/v1/tracks/5LNiqEqpDc8TuqPy79kDBu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5LNiqEqpDc8TuqPy79kDBu',
#   'duration_ms': 329413,
#   'time_signature': 4},
#  {'danceability': 0.345,
#   'energy': 0.612,
#   'key': 7,
#   'loudness': -6.543,
#   'mode': 0,
#   'speechiness': 0.0608,
#   'acousticness': 0.232,
#   'instrumentalness': 0,
#   'liveness': 0.194,
#   'valence': 0.232,
#   'tempo': 179.773,
#   'type': 'audio_features',
#   'id': '59CfNbkERJ3NoTXDvoURjj',
#   'uri': 'spotify:track:59CfNbkERJ3NoTXDvoURjj',
#   'track_href': 'https://api.spotify.com/v1/tracks/59CfNbkERJ3NoTXDvoURjj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59CfNbkERJ3NoTXDvoURjj',
#   'duration_ms': 153000,
#   'time_signature': 3},
#  {'danceability': 0.506,
#   'energy': 0.959,
#   'key': 5,
#   'loudness': -5.264,
#   'mode': 0,
#   'speechiness': 0.102,
#   'acousticness': 0.084,
#   'instrumentalness': 0.000655,
#   'liveness': 0.135,
#   'valence': 0.34,
#   'tempo': 133.996,
#   'type': 'audio_features',
#   'id': '0boS4e6uXwp3zAvz1mLxZS',
#   'uri': 'spotify:track:0boS4e6uXwp3zAvz1mLxZS',
#   'track_href': 'https://api.spotify.com/v1/tracks/0boS4e6uXwp3zAvz1mLxZS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0boS4e6uXwp3zAvz1mLxZS',
#   'duration_ms': 213267,
#   'time_signature': 4},
#  {'danceability': 0.705,
#   'energy': 0.806,
#   'key': 9,
#   'loudness': -3.607,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.0132,
#   'instrumentalness': 0.00428,
#   'liveness': 0.0701,
#   'valence': 0.734,
#   'tempo': 103.383,
#   'type': 'audio_features',
#   'id': '4zQuwW24dweWcaX0fEJkP2',
#   'uri': 'spotify:track:4zQuwW24dweWcaX0fEJkP2',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zQuwW24dweWcaX0fEJkP2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zQuwW24dweWcaX0fEJkP2',
#   'duration_ms': 256947,
#   'time_signature': 4},
#  {'danceability': 0.436,
#   'energy': 0.655,
#   'key': 7,
#   'loudness': -8.153,
#   'mode': 1,
#   'speechiness': 0.159,
#   'acousticness': 0.425,
#   'instrumentalness': 0,
#   'liveness': 0.393,
#   'valence': 0.523,
#   'tempo': 139.712,
#   'type': 'audio_features',
#   'id': '3A0ITFj6kbb9CggwtPe55f',
#   'uri': 'spotify:track:3A0ITFj6kbb9CggwtPe55f',
#   'track_href': 'https://api.spotify.com/v1/tracks/3A0ITFj6kbb9CggwtPe55f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3A0ITFj6kbb9CggwtPe55f',
#   'duration_ms': 154749,
#   'time_signature': 4},
#  {'danceability': 0.316,
#   'energy': 0.484,
#   'key': 9,
#   'loudness': -9.11,
#   'mode': 0,
#   'speechiness': 0.0308,
#   'acousticness': 0.000334,
#   'instrumentalness': 0.00445,
#   'liveness': 0.0912,
#   'valence': 0.299,
#   'tempo': 117.363,
#   'type': 'audio_features',
#   'id': '4mn2kNTqiGLwaUR8JdhJ1l',
#   'uri': 'spotify:track:4mn2kNTqiGLwaUR8JdhJ1l',
#   'track_href': 'https://api.spotify.com/v1/tracks/4mn2kNTqiGLwaUR8JdhJ1l',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4mn2kNTqiGLwaUR8JdhJ1l',
#   'duration_ms': 269907,
#   'time_signature': 3},
#  {'danceability': 0.548,
#   'energy': 0.532,
#   'key': 5,
#   'loudness': -7.596,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.186,
#   'instrumentalness': 0.000263,
#   'liveness': 0.217,
#   'valence': 0.405,
#   'tempo': 85.03,
#   'type': 'audio_features',
#   'id': '5FVd6KXrgO9B3JPmC8OPst',
#   'uri': 'spotify:track:5FVd6KXrgO9B3JPmC8OPst',
#   'track_href': 'https://api.spotify.com/v1/tracks/5FVd6KXrgO9B3JPmC8OPst',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FVd6KXrgO9B3JPmC8OPst',
#   'duration_ms': 272394,
#   'time_signature': 4},
#  {'danceability': 0.509,
#   'energy': 0.448,
#   'key': 4,
#   'loudness': -7.552,
#   'mode': 0,
#   'speechiness': 0.0357,
#   'acousticness': 0.00713,
#   'instrumentalness': 0.0137,
#   'liveness': 0.244,
#   'valence': 0.221,
#   'tempo': 156.909,
#   'type': 'audio_features',
#   'id': '5MAK1nd8R6PWnle1Q1WJvh',
#   'uri': 'spotify:track:5MAK1nd8R6PWnle1Q1WJvh',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MAK1nd8R6PWnle1Q1WJvh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MAK1nd8R6PWnle1Q1WJvh',
#   'duration_ms': 230613,
#   'time_signature': 3},
#  {'danceability': 0.513,
#   'energy': 0.916,
#   'key': 4,
#   'loudness': -3.191,
#   'mode': 0,
#   'speechiness': 0.0987,
#   'acousticness': 0.00219,
#   'instrumentalness': 0.00113,
#   'liveness': 0.338,
#   'valence': 0.474,
#   'tempo': 96.095,
#   'type': 'audio_features',
#   'id': '3OWxpc6Zguzep0XKWGxDyc',
#   'uri': 'spotify:track:3OWxpc6Zguzep0XKWGxDyc',
#   'track_href': 'https://api.spotify.com/v1/tracks/3OWxpc6Zguzep0XKWGxDyc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OWxpc6Zguzep0XKWGxDyc',
#   'duration_ms': 158081,
#   'time_signature': 4},
#  {'danceability': 0.666,
#   'energy': 0.454,
#   'key': 6,
#   'loudness': -8.884,
#   'mode': 1,
#   'speechiness': 0.0539,
#   'acousticness': 0.111,
#   'instrumentalness': 0.00013,
#   'liveness': 0.54,
#   'valence': 0.714,
#   'tempo': 79.951,
#   'type': 'audio_features',
#   'id': '3zaSRGFPFnNKY42TUjoGwM',
#   'uri': 'spotify:track:3zaSRGFPFnNKY42TUjoGwM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3zaSRGFPFnNKY42TUjoGwM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3zaSRGFPFnNKY42TUjoGwM',
#   'duration_ms': 168035,
#   'time_signature': 4},
#  {'danceability': 0.681,
#   'energy': 0.64,
#   'key': 8,
#   'loudness': -6.621,
#   'mode': 1,
#   'speechiness': 0.0873,
#   'acousticness': 0.0466,
#   'instrumentalness': 6.37e-06,
#   'liveness': 0.259,
#   'valence': 0.778,
#   'tempo': 94.028,
#   'type': 'audio_features',
#   'id': '3VIpGWhJ4vFjqqGmABxMEs',
#   'uri': 'spotify:track:3VIpGWhJ4vFjqqGmABxMEs',
#   'track_href': 'https://api.spotify.com/v1/tracks/3VIpGWhJ4vFjqqGmABxMEs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3VIpGWhJ4vFjqqGmABxMEs',
#   'duration_ms': 161840,
#   'time_signature': 4},
#  {'danceability': 0.596,
#   'energy': 0.607,
#   'key': 6,
#   'loudness': -6.179,
#   'mode': 0,
#   'speechiness': 0.168,
#   'acousticness': 0.33,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.531,
#   'tempo': 119.882,
#   'type': 'audio_features',
#   'id': '5MWXOo8DJwgODtPGaietNz',
#   'uri': 'spotify:track:5MWXOo8DJwgODtPGaietNz',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MWXOo8DJwgODtPGaietNz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MWXOo8DJwgODtPGaietNz',
#   'duration_ms': 120666,
#   'time_signature': 4},
#  {'danceability': 0.544,
#   'energy': 0.786,
#   'key': 8,
#   'loudness': -2.97,
#   'mode': 1,
#   'speechiness': 0.0501,
#   'acousticness': 0.00991,
#   'instrumentalness': 0,
#   'liveness': 0.169,
#   'valence': 0.446,
#   'tempo': 153.967,
#   'type': 'audio_features',
#   'id': '6Jkm5kUldvIqxzI1Pa7nXH',
#   'uri': 'spotify:track:6Jkm5kUldvIqxzI1Pa7nXH',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Jkm5kUldvIqxzI1Pa7nXH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Jkm5kUldvIqxzI1Pa7nXH',
#   'duration_ms': 157138,
#   'time_signature': 4},
#  {'danceability': 0.859,
#   'energy': 0.405,
#   'key': 4,
#   'loudness': -6.359,
#   'mode': 0,
#   'speechiness': 0.133,
#   'acousticness': 0.0179,
#   'instrumentalness': 0.126,
#   'liveness': 0.108,
#   'valence': 0.646,
#   'tempo': 134.937,
#   'type': 'audio_features',
#   'id': '6tPLIurCFf9MAGYvba94ub',
#   'uri': 'spotify:track:6tPLIurCFf9MAGYvba94ub',
#   'track_href': 'https://api.spotify.com/v1/tracks/6tPLIurCFf9MAGYvba94ub',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tPLIurCFf9MAGYvba94ub',
#   'duration_ms': 153223,
#   'time_signature': 4},
#  {'danceability': 0.725,
#   'energy': 0.796,
#   'key': 8,
#   'loudness': -4.547,
#   'mode': 1,
#   'speechiness': 0.0842,
#   'acousticness': 0.0353,
#   'instrumentalness': 0.000121,
#   'liveness': 0.288,
#   'valence': 0.632,
#   'tempo': 97.029,
#   'type': 'audio_features',
#   'id': '6HoZUmprRfFWO1CaqkiBUP',
#   'uri': 'spotify:track:6HoZUmprRfFWO1CaqkiBUP',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HoZUmprRfFWO1CaqkiBUP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HoZUmprRfFWO1CaqkiBUP',
#   'duration_ms': 212969,
#   'time_signature': 4},
#  {'danceability': 0.482,
#   'energy': 0.718,
#   'key': 10,
#   'loudness': -6.468,
#   'mode': 0,
#   'speechiness': 0.0777,
#   'acousticness': 0.118,
#   'instrumentalness': 0.108,
#   'liveness': 0.274,
#   'valence': 0.41,
#   'tempo': 160.019,
#   'type': 'audio_features',
#   'id': '2RvheiLZEgoDwiHm5BJNhi',
#   'uri': 'spotify:track:2RvheiLZEgoDwiHm5BJNhi',
#   'track_href': 'https://api.spotify.com/v1/tracks/2RvheiLZEgoDwiHm5BJNhi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2RvheiLZEgoDwiHm5BJNhi',
#   'duration_ms': 197396,
#   'time_signature': 4},
#  {'danceability': 0.576,
#   'energy': 0.743,
#   'key': 8,
#   'loudness': -4.695,
#   'mode': 1,
#   'speechiness': 0.0608,
#   'acousticness': 0.00504,
#   'instrumentalness': 0.000856,
#   'liveness': 0.245,
#   'valence': 0.721,
#   'tempo': 83.959,
#   'type': 'audio_features',
#   'id': '2PfPVnXTySxnmX6ljVkZKV',
#   'uri': 'spotify:track:2PfPVnXTySxnmX6ljVkZKV',
#   'track_href': 'https://api.spotify.com/v1/tracks/2PfPVnXTySxnmX6ljVkZKV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2PfPVnXTySxnmX6ljVkZKV',
#   'duration_ms': 192880,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.844,
#   'key': 8,
#   'loudness': -4.017,
#   'mode': 0,
#   'speechiness': 0.0279,
#   'acousticness': 4.72e-05,
#   'instrumentalness': 0.0414,
#   'liveness': 0.288,
#   'valence': 0.361,
#   'tempo': 136.954,
#   'type': 'audio_features',
#   'id': '0ZlhILQ2RLAHANZXSXZmlA',
#   'uri': 'spotify:track:0ZlhILQ2RLAHANZXSXZmlA',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ZlhILQ2RLAHANZXSXZmlA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ZlhILQ2RLAHANZXSXZmlA',
#   'duration_ms': 308291,
#   'time_signature': 4}]

# %% [markdown]
# ## Building the df

# %%
df_=pd.DataFrame(list_of_audio_features)    
df_=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]
df_
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.639   0.912    -2.621       0.0615      0.001070
# 1          0.733   0.477    -6.737       0.0687      0.302000
# 2          0.744   0.736    -5.258       0.2910      0.142000
# 3          0.796   0.777    -4.810       0.0397      0.026100
# 4          0.506   0.817    -5.051       0.0335      0.002720
# 5          0.852   0.671    -9.251       0.0553      0.012000
# 6          0.602   0.905    -4.046       0.0775      0.000202
# 7          0.606   0.620    -5.005       0.0298      0.030100
# 8          0.591   0.804    -7.299       0.0454      0.327000
# 9          0.345   0.612    -6.543       0.0608      0.232000
# 10         0.506   0.959    -5.264       0.1020      0.084000
# 11         0.705   0.806    -3.607       0.0309      0.013200
# 12         0.436   0.655    -8.153       0.1590      0.425000
# 13         0.316   0.484    -9.110       0.0308      0.000334
# 14         0.548   0.532    -7.596       0.0323      0.186000
# 15         0.509   0.448    -7.552       0.0357      0.007130
# 16         0.513   0.916    -3.191       0.0987      0.002190
# 17         0.666   0.454    -8.884       0.0539      0.111000
# 18         0.681   0.640    -6.621       0.0873      0.046600
# 19         0.596   0.607    -6.179       0.1680      0.330000
# 20         0.544   0.786    -2.970       0.0501      0.009910
# 21         0.859   0.405    -6.359       0.1330      0.017900
# 22         0.725   0.796    -4.547       0.0842      0.035300
# 23         0.482   0.718    -6.468       0.0777      0.118000
# 24         0.576   0.743    -4.695       0.0608      0.005040
# 25         0.566   0.844    -4.017       0.0279      0.000047
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.0970    0.343  143.448  6nzXkCBOhb2mxctNihOqbb
# 1           0.000003    0.0579    0.545   62.507  3mRLHiSHYtC8Hk7bzZdUs1
# 2           0.000011    0.1100    0.770  103.993  1ddKUwm3UuvcMWLLAgOIcX
# 3           0.000358    0.1210    0.787  132.722  4wH4dJgrsxONID6KS2tDQM
# 4           0.000000    0.0486    0.506  109.952  2DgdHcjWmO3qd50RzuBLgZ
# 5           0.063000    0.1030    0.886  129.003  5kcERXTIoNbkBjb6o4vYBf
# 6           0.064000    0.1170    0.411  128.019  4VqPOruhp5EdPBeR92t6lQ
# 7           0.091600    0.1670    0.543   88.984  1qwno7xb5mJe71xtMS6jl2
# 8           0.000006    0.0818    0.658  111.457  5LNiqEqpDc8TuqPy79kDBu
# 9           0.000000    0.1940    0.232  179.773  59CfNbkERJ3NoTXDvoURjj
# 10          0.000655    0.1350    0.340  133.996  0boS4e6uXwp3zAvz1mLxZS
# 11          0.004280    0.0701    0.734  103.383  4zQuwW24dweWcaX0fEJkP2
# 12          0.000000    0.3930    0.523  139.712  3A0ITFj6kbb9CggwtPe55f
# 13          0.004450    0.0912    0.299  117.363  4mn2kNTqiGLwaUR8JdhJ1l
# 14          0.000263    0.2170    0.405   85.030  5FVd6KXrgO9B3JPmC8OPst
# 15          0.013700    0.2440    0.221  156.909  5MAK1nd8R6PWnle1Q1WJvh
# 16          0.001130    0.3380    0.474   96.095  3OWxpc6Zguzep0XKWGxDyc
# 17          0.000130    0.5400    0.714   79.951  3zaSRGFPFnNKY42TUjoGwM
# 18          0.000006    0.2590    0.778   94.028  3VIpGWhJ4vFjqqGmABxMEs
# 19          0.000000    0.1030    0.531  119.882  5MWXOo8DJwgODtPGaietNz
# 20          0.000000    0.1690    0.446  153.967  6Jkm5kUldvIqxzI1Pa7nXH
# 21          0.126000    0.1080    0.646  134.937  6tPLIurCFf9MAGYvba94ub
# 22          0.000121    0.2880    0.632   97.029  6HoZUmprRfFWO1CaqkiBUP
# 23          0.108000    0.2740    0.410  160.019  2RvheiLZEgoDwiHm5BJNhi
# 24          0.000856    0.2450    0.721   83.959  2PfPVnXTySxnmX6ljVkZKV
# 25          0.041400    0.2880    0.361  136.954  0ZlhILQ2RLAHANZXSXZmlA
#
#     duration_ms
# 0        227520
# 1        216133
# 2        172758
# 3        258893
# 4        208707
# 5        178600
# 6        304840
# 7        231600
# 8        329413
# 9        153000
# 10       213267
# 11       256947
# 12       154749
# 13       269907
# 14       272394
# 15       230613
# 16       158081
# 17       168035
# 18       161840
# 19       120666
# 20       157138
# 21       153223
# 22       212969
# 23       197396
# 24       192880
# 25       308291

# %% [markdown]
# ### Adding song name to df

# %%
df_.insert(11,"song",song_name)

# %%
df_
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.639   0.912    -2.621       0.0615      0.001070
# 1          0.733   0.477    -6.737       0.0687      0.302000
# 2          0.744   0.736    -5.258       0.2910      0.142000
# 3          0.796   0.777    -4.810       0.0397      0.026100
# 4          0.506   0.817    -5.051       0.0335      0.002720
# 5          0.852   0.671    -9.251       0.0553      0.012000
# 6          0.602   0.905    -4.046       0.0775      0.000202
# 7          0.606   0.620    -5.005       0.0298      0.030100
# 8          0.591   0.804    -7.299       0.0454      0.327000
# 9          0.345   0.612    -6.543       0.0608      0.232000
# 10         0.506   0.959    -5.264       0.1020      0.084000
# 11         0.705   0.806    -3.607       0.0309      0.013200
# 12         0.436   0.655    -8.153       0.1590      0.425000
# 13         0.316   0.484    -9.110       0.0308      0.000334
# 14         0.548   0.532    -7.596       0.0323      0.186000
# 15         0.509   0.448    -7.552       0.0357      0.007130
# 16         0.513   0.916    -3.191       0.0987      0.002190
# 17         0.666   0.454    -8.884       0.0539      0.111000
# 18         0.681   0.640    -6.621       0.0873      0.046600
# 19         0.596   0.607    -6.179       0.1680      0.330000
# 20         0.544   0.786    -2.970       0.0501      0.009910
# 21         0.859   0.405    -6.359       0.1330      0.017900
# 22         0.725   0.796    -4.547       0.0842      0.035300
# 23         0.482   0.718    -6.468       0.0777      0.118000
# 24         0.576   0.743    -4.695       0.0608      0.005040
# 25         0.566   0.844    -4.017       0.0279      0.000047
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.0970    0.343  143.448  6nzXkCBOhb2mxctNihOqbb
# 1           0.000003    0.0579    0.545   62.507  3mRLHiSHYtC8Hk7bzZdUs1
# 2           0.000011    0.1100    0.770  103.993  1ddKUwm3UuvcMWLLAgOIcX
# 3           0.000358    0.1210    0.787  132.722  4wH4dJgrsxONID6KS2tDQM
# 4           0.000000    0.0486    0.506  109.952  2DgdHcjWmO3qd50RzuBLgZ
# 5           0.063000    0.1030    0.886  129.003  5kcERXTIoNbkBjb6o4vYBf
# 6           0.064000    0.1170    0.411  128.019  4VqPOruhp5EdPBeR92t6lQ
# 7           0.091600    0.1670    0.543   88.984  1qwno7xb5mJe71xtMS6jl2
# 8           0.000006    0.0818    0.658  111.457  5LNiqEqpDc8TuqPy79kDBu
# 9           0.000000    0.1940    0.232  179.773  59CfNbkERJ3NoTXDvoURjj
# 10          0.000655    0.1350    0.340  133.996  0boS4e6uXwp3zAvz1mLxZS
# 11          0.004280    0.0701    0.734  103.383  4zQuwW24dweWcaX0fEJkP2
# 12          0.000000    0.3930    0.523  139.712  3A0ITFj6kbb9CggwtPe55f
# 13          0.004450    0.0912    0.299  117.363  4mn2kNTqiGLwaUR8JdhJ1l
# 14          0.000263    0.2170    0.405   85.030  5FVd6KXrgO9B3JPmC8OPst
# 15          0.013700    0.2440    0.221  156.909  5MAK1nd8R6PWnle1Q1WJvh
# 16          0.001130    0.3380    0.474   96.095  3OWxpc6Zguzep0XKWGxDyc
# 17          0.000130    0.5400    0.714   79.951  3zaSRGFPFnNKY42TUjoGwM
# 18          0.000006    0.2590    0.778   94.028  3VIpGWhJ4vFjqqGmABxMEs
# 19          0.000000    0.1030    0.531  119.882  5MWXOo8DJwgODtPGaietNz
# 20          0.000000    0.1690    0.446  153.967  6Jkm5kUldvIqxzI1Pa7nXH
# 21          0.126000    0.1080    0.646  134.937  6tPLIurCFf9MAGYvba94ub
# 22          0.000121    0.2880    0.632   97.029  6HoZUmprRfFWO1CaqkiBUP
# 23          0.108000    0.2740    0.410  160.019  2RvheiLZEgoDwiHm5BJNhi
# 24          0.000856    0.2450    0.721   83.959  2PfPVnXTySxnmX6ljVkZKV
# 25          0.041400    0.2880    0.361  136.954  0ZlhILQ2RLAHANZXSXZmlA
#
#     duration_ms                               song
# 0        227520                          Bad Girls
# 1        216133                              River
# 2        172758             Fuck Up the Friendship
# 3        258893                           Maneater
# 4        208707                  House of Memories
# 5        178600                   a woman is a god
# 6        304840                           Uprising
# 7        231600                        High Enough
# 8        329413  Edge of Seventeen - 2016 Remaster
# 9        153000                          Boyfriend
# 10       213267                        Run Boy Run
# 11       256947               You Know I'm No Good
# 12       154749                              Venom
# 13       269907            House of the Rising Sun
# 14       272394                   Do I Wanna Know?
# 15       230613                          I See Red
# 16       158081                           CASUALTY
# 17       168035                I've Got A Bad Side
# 18       161840                       Whatshisface
# 19       120666                  cinderella's dead
# 20       157138         10 Things I Hate About You
# 21       153223                         Dead To Me
# 22       212969           Women Don't Owe You Sh*t
# 23       197396                         Rise Again
# 24       192880                      Bed Behaviour
# 25       308291                      Wild Women Do

# %% [markdown]
# ### adding artist name to df

# %%
df_.insert(12,"artist",artist_name)

# %% [markdown]
# # Connect code to one function
#
#         get_features_df

# %%
def get_features_df(username, playlist_id):
    list_of_audio_features=[]
    artist_name=[]
    song_name=[]
    
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
        
#getting features per song in  playlist 
    for value in range(0,len(tracks)):
        #print (songs[value]["track"]["id"])
        list_of_audio_features.append(sp.audio_features(tracks[value]["track"]["id"])[0])
    
# getting  artist name per song in playlist
    for a_name in range(0,len(tracks)):
        #print (songs[a_name]["track"]["artists"][a_name]["name"])
        artist_name.append(tracks[a_name]["track"]["artists"][0]["name"])  

#getting  artist name per song in playlist   
    for s_name in range(0,len(tracks)):
        #print (songs[s_name]["track"]["name"])
        song_name.append(tracks[s_name]["track"]["name"])

# creating df with audio features and adding song name and artist     
    df=pd.DataFrame(list_of_audio_features)    
    df=df[["danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo","id","duration_ms"]]
    df.insert(0,"song", song_name)
    df.insert(1,"artist", artist_name)
    
    return df

# %%
#TEST - worked
get_features_df("familie.oeljeklaus","2RHNBm388mdIGQyH3ZGkaY")
# Out:
#                                  song                     artist  \
# 0                           Bad Girls                     M.I.A.
# 1                               River              Bishop Briggs
# 2              Fuck Up the Friendship                  Leah Kate
# 3                            Maneater              Nelly Furtado
# 4                   House of Memories        Panic! At The Disco
# 5                    a woman is a god              Tommy Genesis
# 6                            Uprising                       Muse
# 7                         High Enough                     K.Flay
# 8   Edge of Seventeen - 2016 Remaster               Stevie Nicks
# 9                           Boyfriend               Dove Cameron
# 10                        Run Boy Run                    Woodkid
# 11               You Know I'm No Good              Amy Winehouse
# 12                              Venom                Little Simz
# 13            House of the Rising Sun                The Animals
# 14                   Do I Wanna Know?             Arctic Monkeys
# 15                          I See Red  Everybody Loves an Outlaw
# 16                           CASUALTY                    MOTHICA
# 17                I've Got A Bad Side                      ADONA
# 18                       Whatshisface                      OSTON
# 19                  cinderella's dead                    EMELINE
# 20         10 Things I Hate About You                  Leah Kate
# 21                         Dead To Me                Chloe Adams
# 22           Women Don't Owe You Sh*t                      ASTON
# 23                         Rise Again                       LITO
# 24                      Bed Behaviour                       LITO
# 25                      Wild Women Do                   DJ 90210
#
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.639   0.912    -2.621       0.0615      0.001070
# 1          0.733   0.477    -6.737       0.0687      0.302000
# 2          0.744   0.736    -5.258       0.2910      0.142000
# 3          0.796   0.777    -4.810       0.0397      0.026100
# 4          0.506   0.817    -5.051       0.0335      0.002720
# 5          0.852   0.671    -9.251       0.0553      0.012000
# 6          0.602   0.905    -4.046       0.0775      0.000202
# 7          0.606   0.620    -5.005       0.0298      0.030100
# 8          0.591   0.804    -7.299       0.0454      0.327000
# 9          0.345   0.612    -6.543       0.0608      0.232000
# 10         0.506   0.959    -5.264       0.1020      0.084000
# 11         0.705   0.806    -3.607       0.0309      0.013200
# 12         0.436   0.655    -8.153       0.1590      0.425000
# 13         0.316   0.484    -9.110       0.0308      0.000334
# 14         0.548   0.532    -7.596       0.0323      0.186000
# 15         0.509   0.448    -7.552       0.0357      0.007130
# 16         0.513   0.916    -3.191       0.0987      0.002190
# 17         0.666   0.454    -8.884       0.0539      0.111000
# 18         0.681   0.640    -6.621       0.0873      0.046600
# 19         0.596   0.607    -6.179       0.1680      0.330000
# 20         0.544   0.786    -2.970       0.0501      0.009910
# 21         0.859   0.405    -6.359       0.1330      0.017900
# 22         0.725   0.796    -4.547       0.0842      0.035300
# 23         0.482   0.718    -6.468       0.0777      0.118000
# 24         0.576   0.743    -4.695       0.0608      0.005040
# 25         0.566   0.844    -4.017       0.0279      0.000047
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.0970    0.343  143.448  6nzXkCBOhb2mxctNihOqbb
# 1           0.000003    0.0579    0.545   62.507  3mRLHiSHYtC8Hk7bzZdUs1
# 2           0.000011    0.1100    0.770  103.993  1ddKUwm3UuvcMWLLAgOIcX
# 3           0.000358    0.1210    0.787  132.722  4wH4dJgrsxONID6KS2tDQM
# 4           0.000000    0.0486    0.506  109.952  2DgdHcjWmO3qd50RzuBLgZ
# 5           0.063000    0.1030    0.886  129.003  5kcERXTIoNbkBjb6o4vYBf
# 6           0.064000    0.1170    0.411  128.019  4VqPOruhp5EdPBeR92t6lQ
# 7           0.091600    0.1670    0.543   88.984  1qwno7xb5mJe71xtMS6jl2
# 8           0.000006    0.0818    0.658  111.457  5LNiqEqpDc8TuqPy79kDBu
# 9           0.000000    0.1940    0.232  179.773  59CfNbkERJ3NoTXDvoURjj
# 10          0.000655    0.1350    0.340  133.996  0boS4e6uXwp3zAvz1mLxZS
# 11          0.004280    0.0701    0.734  103.383  4zQuwW24dweWcaX0fEJkP2
# 12          0.000000    0.3930    0.523  139.712  3A0ITFj6kbb9CggwtPe55f
# 13          0.004450    0.0912    0.299  117.363  4mn2kNTqiGLwaUR8JdhJ1l
# 14          0.000263    0.2170    0.405   85.030  5FVd6KXrgO9B3JPmC8OPst
# 15          0.013700    0.2440    0.221  156.909  5MAK1nd8R6PWnle1Q1WJvh
# 16          0.001130    0.3380    0.474   96.095  3OWxpc6Zguzep0XKWGxDyc
# 17          0.000130    0.5400    0.714   79.951  3zaSRGFPFnNKY42TUjoGwM
# 18          0.000006    0.2590    0.778   94.028  3VIpGWhJ4vFjqqGmABxMEs
# 19          0.000000    0.1030    0.531  119.882  5MWXOo8DJwgODtPGaietNz
# 20          0.000000    0.1690    0.446  153.967  6Jkm5kUldvIqxzI1Pa7nXH
# 21          0.126000    0.1080    0.646  134.937  6tPLIurCFf9MAGYvba94ub
# 22          0.000121    0.2880    0.632   97.029  6HoZUmprRfFWO1CaqkiBUP
# 23          0.108000    0.2740    0.410  160.019  2RvheiLZEgoDwiHm5BJNhi
# 24          0.000856    0.2450    0.721   83.959  2PfPVnXTySxnmX6ljVkZKV
# 25          0.041400    0.2880    0.361  136.954  0ZlhILQ2RLAHANZXSXZmlA
#
#     duration_ms
# 0        227520
# 1        216133
# 2        172758
# 3        258893
# 4        208707
# 5        178600
# 6        304840
# 7        231600
# 8        329413
# 9        153000
# 10       213267
# 11       256947
# 12       154749
# 13       269907
# 14       272394
# 15       230613
# 16       158081
# 17       168035
# 18       161840
# 19       120666
# 20       157138
# 21       153223
# 22       212969
# 23       197396
# 24       192880
# 25       308291

# %% [markdown]
# # Creating the loop
#
# ## Test with 2 small playlists

# %%
playlist= {"username":["familie.oeljeklaus","paulraensch"]
               ,"playlist_id":["2RHNBm388mdIGQyH3ZGkaY","6CDTDuRKy2Ze2nmmYFAIBK"]}

# %%
username=["familie.oeljeklaus","paulraensch"]
playlist_id=["2RHNBm388mdIGQyH3ZGkaY","6CDTDuRKy2Ze2nmmYFAIBK"]

# %%
username[0]
# Out:
# 'familie.oeljeklaus'

# %%
list(zip(username, playlist_id))
# Out:
# [('familie.oeljeklaus', '2RHNBm388mdIGQyH3ZGkaY'),
#  ('paulraensch', '6CDTDuRKy2Ze2nmmYFAIBK')]

# %%
for i, j in list(zip(playlist["username"][i], playlist["playlist_id"][j])):
    get_features_df(i,j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [561], in <cell line: 1>()
# ----> 1 for i, j in list(zip(playlist["username"][i], playlist["playlist_id"][j])):
#       2     get_features_df(i,j)
#
# TypeError: list indices must be integers or slices, not str

# %%
for i, j in list(zip(username, playlist_id)):
    get_features_df(i,j)
    df

# %%
df

# %% [markdown]
# # collect different playlist
#
# 1. Collect playists id by webscraping

# %%
url = "https://popkultur.de/die-besten-spotify-playlists/"
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = bs(response.content, "html.parser")

# %%
x=soup.select("iframe")[0]["data-lazy-src"]
# Out:
# 'https://open.spotify.com/embed/playlist/37i9dQZF1DXcBWIGoYBM5M'

# %%
# adding 
for playlist_id in soup.select("iframe")[playlist]["data-lazy-src"]:
    response = urllib2.urlopen(iframe.attrs['src'])
    iframe_soup = bs(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [565], in <cell line: 1>()
#       1 for iframe in soup.select("iframe"):
# ----> 2     response = urllib2.urlopen(iframe.attrs['src'])
#       3     iframe_soup = bs(response)
#
# NameError: name 'urllib2' is not defined
