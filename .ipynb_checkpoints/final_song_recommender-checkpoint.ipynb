# %% [markdown]
# #  Import usefull packages

# %%
import spotipy
from IPython.display import IFrame
import pandas as pd
import json
import pprint
import config
from itertools import *
from bs4 import BeautifulSoup as bs
import sys
import random
import requests
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
sp= spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,client_secret=config.client_secret))

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
from sklearn.compose import ColumnTransformer

# %%
from termcolor import colored
from textblob import TextBlob
import getpass
import difflib
import tkinter as tk
import random

# %% [markdown]
# # import the clustered data frame from clustering

# %%
db_version_6000= pd.read_csv("db/first_try_6000.csv")

# %%
db_version_6000
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.865   0.665    -6.289       0.0730      0.045300
# 1            0.801   0.910    -6.566       0.2250      0.002390
# 2            0.644   0.846    -5.443       0.2750      0.124000
# 3            0.802   0.787    -6.009       0.2060      0.001270
# 4            0.872   0.723    -5.968       0.2470      0.029300
# ...            ...     ...       ...          ...           ...
# 6378         0.791   0.591    -9.185       0.0478      0.017200
# 6379         0.655   0.794    -5.872       0.2500      0.082000
# 6380         0.757   0.920    -7.697       0.0385      0.000531
# 6381         0.826   0.900    -7.707       0.0697      0.066600
# 6382         0.745   0.853    -8.154       0.0407      0.003340
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster  \
# 0             0.000000    0.2240    0.331  111.113       268827        0
# 1             0.000891    0.0737    0.805   87.277       278387        0
# 2             0.000000    0.3530    0.503   79.182       301600        2
# 3             0.000181    0.0763    0.806   90.189       296907        0
# 4             0.000000    0.3270    0.843   93.279       307773        0
# ...                ...       ...      ...      ...          ...      ...
# 6378          0.879000    0.1310    0.683  133.974       428606        0
# 6379          0.079100    0.0457    0.667  187.007       184939        0
# 6380          0.751000    0.0956    0.955  126.001       327304        0
# 6381          0.275000    0.6790    0.925  120.980       306641        2
# 6382          0.403000    0.1350    0.466  124.011       254091        0
#
#                           id
# 0     1ofhfV90EnYhEr7Un2fWiv
# 1     5g9lS8deSIxItFBmZRC4vN
# 2     1qZqFtSINOOmjYH1UE9805
# 3     7sKt5Y2zJpYw78iAxndB8y
# 4     4VQNCzfZ3MdHEwwErNXpBo
# ...                      ...
# 6378  4LWiFuehm2uY3GK8q8sduT
# 6379  3cCLvbMCHMgX7DLXPr1ALv
# 6380  2MumLWIryjcBG1eRYcRh6I
# 6381  5z0J0ztN5QG0UTRv3wSZQK
# 6382  6k5dL3jGlbliaIQRqkAGcU
#
# [6383 rows x 12 columns]

# %% [markdown]
# ##  store id and clustr column in other df

# %%
db_version_6000_id=db_version_6000["id"]
db_version_6000_cluster=db_version_6000["cluster"]

# %% [markdown]
# ## drop id and cluster column
#           we are gonna use db_version_6000

# %%
db_version_6000.drop("id",axis=1, inplace=True)
db_version_6000.drop("cluster",axis=1, inplace=True)

# %% [markdown]
# ## adding them all together again for recommending

# %%
db_version_6000_all= pd.concat([db_version_6000_id,db_version_6000_cluster,db_version_6000],axis=1)

# %% [markdown]
# # Load functions

# %%
## EMBBEDED SONG PLAYER
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="100",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
def load(filename = "get_features_df.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
def load(filename = "scaler.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
scaler=load(filename = "Model/scaler.pickle")

# %%
def load(filename = "hot_100.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
hot_100=load(filename = "Model/hot_100.pickle")

# %%
def load(filename = "song_list.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
song_list=load(filename = "Model/song_list.pickle")

# %%
## KMEANS MODEL from CLUSTERING
def load(filename = "kmeans_6.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
kmeans_6=load(filename = "Model/kmeans_6.pickle")

# %% [markdown]
# # Define function

# %% [markdown]
# 1. [x] get the song name from the user as an input
# 2. [x]  play the input song in music embed player.
# 3.  [x] get the audio features for that song from spotify API. using sp.audio_features(trackid) . pay attention to keep only the audio features columns.
# 4.  [x] load the standardscaler using pickle and use it to scale the new song. (scaler.transform)
# 5. [x] using mode.predict(new scaled audio record for the new song) to predict the cluster (label) for the new song.
# 6. [x] return random song from the same cluster that the new song belongs to from your data frame and suggest it to the user.
# 7. [x] play it using embedded music player.

# %%
def song_recommend():
    welcome = """
************************************************************
*                                                          *
*                  Welcome to the greatest                 *
*                    song recommender!                     *
*                                                          *
************************************************************
"""
    print(welcome)
    
    # INPUT    
    input_song=str.lower((input("Insert a song you like:  ")))
    #correct=difflib.get_close_matches(input_song, song_list)
    results = sp.search(q=input_song,type="track",market="DE")
    track_id=results["tracks"]["items"][0]["id"]
    a=results["tracks"]["items"][0]["artists"][0]["name"]
    s=results["tracks"]["items"][0]["name"]      

    print("Did you mean this song: ", colored(s,"blue",attrs=["bold"]), " by ",colored(a,"green",attrs=["bold"]),"?")
    print()
    print("Press Y for yes or N for no")

    display(play_song(track_id))
    accept__= str.lower(input(" "))
    
    
    #TOP 100
    if accept__=="y":
        
        if any(input_song in s for s in song_list):
            matching = [s for s in song_list if input_song in s]
        
            if len(matching)<2:
                rec=pd.DataFrame(hot_100.sample().reset_index())
                title=rec["title"].values[0]
                artist= hot_100.loc[hot_100["title"]==title]["artist"].values[0]
            
                hot_rec= sp.search(q=title and artist,limit=1,market="DE")
            
                track_id=hot_rec["tracks"]["items"][0]["id"]
                a=hot_rec["tracks"]["items"][0]["artists"][0]["name"]
                s=hot_rec["tracks"]["items"][0]["name"]
            
                print()
                print("Your choosen song is currently in the Bilboard Top 100. \nWe assume that you would also enjoy \n")
                print()
                print ("You should try listening to ",colored(rec["title"][0].capitalize(), 'blue', attrs=['bold'])," from ",colored(rec["artist"][0].capitalize(), 'green', attrs=['bold']),"!")
                print("------------------------------------------------------------------")
                print()
                display(play_song(track_id))
            
            
            else: 
                print("Do you mean any of the following songs. Enter", colored("Y", "green", attrs=["bold"]), "for yes and ", colored("N","red",attrs=["bold"])," for no")
            
                for i in range(0, len(matching)):
                    print(colored(matching[i].capitalize(),"blue",attrs=["bold"]))
            
                input_correct=str.lower(input(""))
            
                if input_correct == "y":
                    rec=pd.DataFrame(hot_100.sample().reset_index())
                    title=rec["title"].values[0]
                    artist= hot_100.loc[hot_100["title"]==title]["artist"].values[0]

                    hot_rec= sp.search(q=title and artist,limit=1,market="DE")

                    track_id=hot_rec["tracks"]["items"][0]["id"]
                    a=hot_rec["tracks"]["items"][0]["artists"][0]["name"]
                    s=hot_rec["tracks"]["items"][0]["name"]

                    print ("You should try listening to ", colored(rec["title"][0].capitalize(),"blue",attrs=["bold"])," from ", colored(rec["artist"][0].capitalize(),"green", attrs=["bold"]),"!") 
                    print("------------------------------------------------------------------")
                    print()
                    display(play_song(track_id))
            
                
        else:    
    # DID YOU MEAN THIS SONG??        
            results = sp.search(q=input_song,type="track",market="DE")

            while accept__ =="n":
                for i in range(1, 4):
                    track_id=results["tracks"]["items"][i]["id"]
                    a=results["tracks"]["items"][i]["artists"][0]["name"]
                    s=results["tracks"]["items"][i]["name"]      

                    print("Did you mean this song: ", colored(s,"blue",attrs=["bold"]), " by ",colored(a,"green",attrs=["bold"]),"?")
                    print()
                    print("Press Y for yes or N for no")

                    display(play_song(track_id))
                    accept__= str.lower(input(" "))
                    if accept__ == "y":
                        break


            user_song_features=sp.audio_features(track_id)[0]
            df_user_song=pd.DataFrame(user_song_features,index=[0])
            df_user_song=df_user_song[["danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo","duration_ms"]]

            # Std Scale the AUDIO FEATURES DF
            scaler.fit(db_version_6000)
            df_user_song_scaled_values = scaler.transform(df_user_song)
            df_user_song_scaled = pd.DataFrame(df_user_song_scaled_values , columns = df_user_song.columns)

            # PREDICT CLUSTER for USER SONG
            kmeans_6.fit(db_version_6000)
            clusters = kmeans_6.predict(df_user_song_scaled)
            cluster_user_song=clusters[0]

            # RANDOM RECOMMENDATION
            sample= db_version_6000_all[db_version_6000_all.cluster==cluster_user_song].sample()
            rec_song_id=sample["id"].values[0]

            # SHOW REC SONG
            display(play_song(rec_song_id))

    return

# %%
song_recommend()
# Out:
# ************************************************************
# *                                                          *
# *                  Welcome to the greatest                 *
# *                    song recommender!                     *
# *                                                          *
# ************************************************************
#
# Insert a song you like:  you
# Did you mean this song:  YOU  by  Phil The Beat ?
#
# Press Y for yes or N for no
#         <iframe
#             width="320"
#             height="100"
#             src="https://open.spotify.com/embed/track/6cVNYlO75XZ3UZnglTF6WI?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#  n

# %% [markdown]
# # Second attempt

# %%
def song_recommender():
    welcome = """
************************************************************
*                                                          *
*                  Welcome to the greatest                 *
*                    song recommender!                     *
*                                                          *
************************************************************
"""
    print(welcome)
    
    # INPUT    
    input_song=str.lower((input("Insert a song you like:  ")))
    
    if any(input_song in s for s in song_list):
            matching = [s for s in song_list if input_song in s]
        
            if len(matching)<2:
                rec=pd.DataFrame(hot_100.sample().reset_index())
                title=rec["title"].values[0]
                artist= hot_100.loc[hot_100["title"]==title]["artist"].values[0]
            
                hot_rec= sp.search(q=title and artist,limit=1,market="DE")
            
                track_id=hot_rec["tracks"]["items"][0]["id"]
                a=hot_rec["tracks"]["items"][0]["artists"][0]["name"]
                s=hot_rec["tracks"]["items"][0]["name"]
            
                print()
                print("Your choosen song is currently in the Bilboard Top 100. \nWe assume that you would also enjoy \n")
                print()
                print ("You should try listening to ",colored(rec["title"][0].capitalize(), 'blue', attrs=['bold'])," from ",colored(rec["artist"][0].capitalize(), 'green', attrs=['bold']),"!")
                print("------------------------------------------------------------------")
                print()
                display(play_song(track_id))
            
            
            else: 
                print("Do you mean any of the following songs. Enter", colored("Y", "green", attrs=["bold"]), "for yes and ", colored("N","red",attrs=["bold"])," for no")
            
                for i in range(0, len(matching)):
                    print(colored(matching[i].capitalize(),"blue",attrs=["bold"]))
            
                input_correct=str.lower(input(""))
            
                if input_correct == "y":
                    rec=pd.DataFrame(hot_100.sample().reset_index())
                    title=rec["title"].values[0]
                    artist= hot_100.loc[hot_100["title"]==title]["artist"].values[0]

                    hot_rec= sp.search(q=title and artist,limit=1,market="DE")

                    track_id=hot_rec["tracks"]["items"][0]["id"]
                    a=hot_rec["tracks"]["items"][0]["artists"][0]["name"]
                    s=hot_rec["tracks"]["items"][0]["name"]

                    print()
                    print("Your choosen song is currently in the Bilboard Top 100. \nWe assume that you would also enjoy \n")
                    print()
                    print ("You should try listening to ", colored(rec["title"][0].capitalize(),"blue",attrs=["bold"])," from ", colored(rec["artist"][0].capitalize(),"green", attrs=["bold"]),"!") 
                    print()
                    print("------------------------------------------------------------------")
                    print()
                    display(play_song(track_id))
    
    else:    
        results = sp.search(q=input_song,type="track",market="DE")
        track_id=results["tracks"]["items"][0]["id"]
        a=results["tracks"]["items"][0]["artists"][0]["name"]
        s=results["tracks"]["items"][0]["name"]      

        print("Did you mean this song: ", colored(s,"blue",attrs=["bold"]), " by ",colored(a,"green",attrs=["bold"]),"?")
        print()
        print("Press Y for yes or N for no")

        display(play_song(track_id))
        accept__= str.lower(input(" "))
        
        while accept__ =="n":
            for i in range(1, 4):
                track_id=results["tracks"]["items"][i]["id"]
                a=results["tracks"]["items"][i]["artists"][0]["name"]
                s=results["tracks"]["items"][i]["name"]      

                print("Did you mean this song: ", colored(s,"blue",attrs=["bold"]), " by ",colored(a,"green",attrs=["bold"]),"?")
                print()
                print("Press Y for yes or N for no")

                display(play_song(track_id))
                accept__= str.lower(input(" "))
                if accept__ == "y":
                    break


        user_song_features=sp.audio_features(track_id)[0]
        df_user_song=pd.DataFrame(user_song_features,index=[0])
        df_user_song=df_user_song[["danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo","duration_ms"]]

        # Std Scale the AUDIO FEATURES DF
        scaler.fit(db_version_6000)
        df_user_song_scaled_values = scaler.transform(df_user_song)
        df_user_song_scaled = pd.DataFrame(df_user_song_scaled_values , columns = df_user_song.columns)

        # PREDICT CLUSTER for USER SONG
        kmeans_6.fit(db_version_6000)
        clusters = kmeans_6.predict(df_user_song_scaled)
        cluster_user_song=clusters[0]

        # RANDOM RECOMMENDATION
        sample= db_version_6000_all[db_version_6000_all.cluster==cluster_user_song].sample()
        rec_song_id=sample["id"].values[0]

        # SHOW REC SONG
        print ("You should try listening to ", colored(s,"blue",attrs=["bold"])," from ", colored(a,"green", attrs=["bold"]),"!") 
        print()
        print("------------------------------------------------------------------")
        print()
        display(play_song(rec_song_id))
       

    return

# %%
song_recommender()
# Out:
# ************************************************************
# *                                                          *
# *                  Welcome to the greatest                 *
# *                    song recommender!                     *
# *                                                          *
# ************************************************************
#
# Insert a song you like:  as it was
#
# Your choosen song is currently in the Bilboard Top 100.
# We assume that you would also enjoy
#
#
# You should try listening to  Rock and a hard place  from  Bailey zimmerman !
# ------------------------------------------------------------------
#         <iframe
#             width="320"
#             height="100"
#             src="https://open.spotify.com/embed/track/4686eQ81DEswHa90bcdlC9?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
